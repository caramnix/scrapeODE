# %%
import time 
import pandas as pd 
from selenium import webdriver 
from selenium.webdriver import Chrome 
from selenium.webdriver.chrome.service import Service 
from selenium.webdriver.common.by import By 
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import ElementClickInterceptedException, NoSuchElementException
from selenium import webdriver

# %%
##set chromodriver.exe path
#driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")
#driver.implicitly_wait(0.5)

# %%
years_list= ['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']  
final_val_list=["Final #3", "Final #5", "Final #4", "Final #3", 'Final #2', 'Final #1', 'Final #2', 'Final #2']

# %%
def get_school_list(year, final_val): 
    time.sleep(1)
    driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")
    driver.implicitly_wait(0.5)
    url = "https://reports.education.ohio.gov/finance/legacy-report" 
    driver.get(url)
    driver.implicitly_wait(10)
    time.sleep(3)

    ## scrape 2000
    YEAR = year
    FINAL = final_val
    #first step, fill in info, press go 

    # fill in LEA type 
    text_box_path = '/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input'
    text_box = driver.find_element(By.XPATH, text_box_path)
    text_box.send_keys("Traditional School District")

    text_box_selection_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div"
    time.sleep(.25)
    drop_box_1 = driver.find_element(By.XPATH, text_box_selection_path)
    time.sleep(.25)
    drop_box_1.click()

    #fill in year 
    year_text_box_path ="/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[2]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    year_text_box = driver.find_element(By.XPATH, year_text_box_path)
    year_text_box.send_keys(YEAR)

    year_drop_select ="/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[2]/ul/li[2]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"
    time.sleep(.25)
    drop_box_2 = driver.find_element(By.XPATH, year_drop_select)
    time.sleep(.25)
    drop_box_2.click()

    time.sleep(.25)
    go_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[3]/button"
    time.sleep(.25)
    go_button = driver.find_element(By.XPATH, go_path)
    time.sleep(.25)

    go_button_bool = None
    while not go_button_bool:
        try:
            go_button.click()
            go_button_bool=1
        except ElementClickInterceptedException:
            time.sleep(2)

    time.sleep(.25)
    #next step 

    payment_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[3]/div/ul/li/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    payment_path_box = driver.find_element(By.XPATH, payment_path)
    time.sleep(.25)

    payment_path_box.send_keys(FINAL)
    payment_path_selection_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[3]/div/ul/li/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"

    time.sleep(.25)
    drop_box_3 = driver.find_element(By.XPATH, payment_path_selection_path)
    drop_box_3.click()

    #next step is to find all LEA values 

    lea_box_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    lea_arrow_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div"

    #click on arrow to show options 
    driver.find_element(By.XPATH, lea_arrow_path).click()

    time.sleep(.25)
    drop_down_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div"
    drop_down= driver.find_element(By.XPATH, drop_down_path)

    ddt= drop_down.text
    list_school_names_i = ddt.splitlines()
    
    return(list_school_names_i)

# %%
#set chromodriver.exe path
driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")
driver.implicitly_wait(0.5)
# Out:
# /var/folders/09/l3m63nj90fg1l2jshjp_hd5w0000gn/T/ipykernel_22777/553504982.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")

# %%
i=7 #2010
year = years_list[i]
print(year)
final_val = final_val_list[i]
list_school_names= get_school_list(year, final_val) 

colnames= ["IRN", "year", "county_code", 
           "CS_ADM_sped_total_cat1", "CS_ADM_sped_total_cat2", "CS_ADM_sped_total_cat3", "CS_ADM_sped_total_cat4", "CS_ADM_sped_total_cat5", "CS_ADM_sped_total_cat6", 
           "CS_CTA_cat1_FTE", "CS_CTA_cat2_FTE", "CS_CTA_cat3_FTE", "CS_CTA_cat4_FTE", "CS_CTA_cat5_FTE",
           "CS_INT_1", "CS_INT_2", "CS_INT_3",
           "CS_econ_dis_FTE", 'econ_dis_index', 
           "CS_formula_amt", "CS_econ_disadv_funded", "CS_LEP_AID", 
           "CS_sped_wtd_funds", 'CS_CTA_total_funds', 'CS_TRANS_AID', 'CS_TOTAL_DEDUCT']

# %%
df = pd.DataFrame(columns = colnames)

# %%
list_school_names
# Out:
# ['State Totals (All Counties) - 999999',
#  'Ada Exempted Village (Hardin) - 045187',
#  'Adams County Ohio Valley Local (Adams) - 061903',
#  'Adena Local (Ross) - 049494',
#  'Akron City (Summit) - 043489',
#  'Alexander Local (Athens) - 045906',
#  'Allen East Local (Allen) - 045757',
#  'Alliance City (Stark) - 043497',
#  'Amanda-Clearcreek Local (Fairfield) - 046847',
#  'Amherst Exempted Village (Lorain) - 045195',
#  'Anna Local (Shelby) - 049759',
#  'Ansonia Local (Darke) - 046623',
#  'Anthony Wayne Local (Lucas) - 048207',
#  'Antwerp Local (Paulding) - 048991',
#  'Arcadia Local (Hancock) - 047415',
#  'Arcanum-Butler Local (Darke) - 046631',
#  'Archbold-Area Local (Fulton) - 047043',
#  'Arlington Local (Hancock) - 047423',
#  'Ashland City (Ashland) - 043505',
#  'Ashtabula Area City (Ashtabula) - 043513',
#  'Athens City (Athens) - 043521',
#  'Aurora City (Portage) - 049171',
#  'Austintown Local Schools (Mahoning) - 048298',
#  'Avon Lake City (Lorain) - 048124',
#  'Avon Local (Lorain) - 048116',
#  'Ayersville Local (Defiance) - 046706',
#  'Barberton City (Summit) - 043539',
#  'Barnesville Exempted Village (Belmont) - 045203',
#  'Batavia Local (Clermont) - 046300',
#  'Bath Local (Allen) - 045765',
#  'Bay Village City (Cuyahoga) - 043547',
#  'Beachwood City (Cuyahoga) - 043554',
#  'Beaver Local (Columbiana) - 046425',
#  'Beavercreek City (Greene) - 047241',
#  'Bedford City (Cuyahoga) - 043562',
#  'Bellaire Local (Belmont) - 043570',
#  'Bellbrook-Sugarcreek Local (Greene) - 047274',
#  'Bellefontaine City (Logan) - 043588',
#  'Bellevue City (Huron) - 043596',
#  'Belpre City (Washington) - 043604',
#  'Benjamin Logan Local (Logan) - 048074',
#  'Benton Carroll Salem Local (Ottawa) - 048926',
#  'Berea City (Cuyahoga) - 043612',
#  'Berkshire Local (Geauga) - 047167',
#  'Berne Union Local (Fairfield) - 046854',
#  'Bethel Local (Miami) - 048611',
#  'Bethel-Tate Local (Clermont) - 046318',
#  'Bexley City (Franklin) - 043620',
#  'Big Walnut Local (Delaware) - 046748',
#  'Black River Local (Medina) - 048462',
#  'Blanchester Local (Clinton) - 046383',
#  'Bloom-Carroll Local (Fairfield) - 046862',
#  'Bloom-Vernon Local (Scioto) - 049593',
#  'Bloomfield-Mespo Local (Trumbull) - 050096',
#  'Bluffton Exempted Village (Allen) - 045211',
#  'Boardman Local (Mahoning) - 048306',
#  'Botkins Local (Shelby) - 049767',
#  'Bowling Green City School District (Wood) - 043638',
#  'Bradford Exempted Village (Miami) - 045229',
#  'Brecksville-Broadview Heights City (Cuyahoga) - 043646',
#  'Bridgeport Exempted Village (Belmont) - 045237',
#  'Bright Local (Highland) - 047613',
#  'Bristol Local (Trumbull) - 050112',
#  'Brookfield Local (Trumbull) - 050120',
#  'Brooklyn City (Cuyahoga) - 043653',
#  'Brookville Local (Montgomery) - 048678',
#  'Brown Local (Carroll) - 046177',
#  'Brunswick City (Medina) - 043661',
#  'Bryan City (Williams) - 043679',
#  'Buckeye Central Local (Crawford) - 046508',
#  'Buckeye Local (Medina) - 048470',
#  'Buckeye Local (Jefferson) - 047787',
#  'Buckeye Local (Ashtabula) - 045856',
#  'Buckeye Valley Local (Delaware) - 046755',
#  'Bucyrus City (Crawford) - 043687',
#  'Caldwell Exempted Village (Noble) - 045252',
#  'Cambridge City (Guernsey) - 043695',
#  'Campbell City (Mahoning) - 043703',
#  'Canal Winchester Local (Franklin) - 046946',
#  'Canfield Local (Mahoning) - 048314',
#  'Canton City (Stark) - 043711',
#  'Canton Local (Stark) - 049833',
#  'Cardinal Local (Geauga) - 047175',
#  'Cardington-Lincoln Local (Morrow) - 048793',
#  'Carey Exempted Village Schools (Wyandot) - 045260',
#  'Carlisle Local (Warren) - 050419',
#  'Carrollton Exempted Village (Carroll) - 045278',
#  'Cedar Cliff Local (Greene) - 047258',
#  'Celina City (Mercer) - 043729',
#  'Centerburg Local (Knox) - 047829',
#  'Centerville City (Montgomery) - 043737',
#  'Central Local (Defiance) - 046714',
#  'Chagrin Falls Exempted Village (Cuyahoga) - 045286',
#  'Champion Local (Trumbull) - 050138',
#  'Chardon Local (Geauga) - 047183',
#  'Chesapeake Union Exempted Village (Lawrence) - 045294',
#  'Chillicothe City (Ross) - 043745',
#  'Chippewa Local (Wayne) - 050534',
#  'Cincinnati Public Schools (Hamilton) - 043752',
#  'Circleville City (Pickaway) - 043760',
#  'Clark-Shawnee Local (Clark) - 046284',
#  'Clay Local (Scioto) - 049601',
#  'Claymont City (Tuscarawas) - 043778',
#  'Clear Fork Valley Local (Richland) - 049411',
#  'Clearview Local (Lorain) - 048132',
#  'Clermont Northeastern Local (Clermont) - 046326',
#  'Cleveland Heights-University Heights City (Cuyahoga) - 043794',
#  'Cleveland Municipal (Cuyahoga) - 043786',
#  'Clinton-Massie Local (Clinton) - 046391',
#  'Cloverleaf Local (Medina) - 048488',
#  'Clyde-Green Springs Exempted Village (Sandusky) - 045302',
#  'Coldwater Exempted Village (Mercer) - 045310',
#  'College Corner Local (Preble) - 064964',
#  'Colonel Crawford Local (Crawford) - 046516',
#  'Columbia Local (Lorain) - 048140',
#  'Columbiana Exempted Village (Columbiana) - 045328',
#  'Columbus City Schools District (Franklin) - 043802',
#  'Columbus Grove Local (Putnam) - 049312',
#  'Conneaut Area City (Ashtabula) - 043810',
#  'Conotton Valley Union Local (Harrison) - 047548',
#  'Continental Local (Putnam) - 049320',
#  'Copley-Fairlawn City (Summit) - 049981',
#  'Cory-Rawson Local (Hancock) - 047431',
#  'Coshocton City (Coshocton) - 043828',
#  'Coventry Local (Summit) - 049999',
#  'Covington Exempted Village (Miami) - 045336',
#  'Crestline Exempted Village (Crawford) - 045344',
#  'Crestview Local (Columbiana) - 046433',
#  'Crestview Local (Richland) - 049429',
#  'Crestview Local (Van Wert) - 050351',
#  'Crestwood Local (Portage) - 049189',
#  'Crooksville Exempted Village (Perry) - 045351',
#  'Cuyahoga Falls City (Summit) - 043836',
#  'Cuyahoga Heights Local (Cuyahoga) - 046557',
#  'Dalton Local (Wayne) - 050542',
#  'Danbury Local (Ottawa) - 048934',
#  'Danville Local (Knox) - 047837',
#  'Dawson-Bryant Local (Lawrence) - 047928',
#  'Dayton City (Montgomery) - 043844',
#  'Deer Park Community City (Hamilton) - 043851',
#  'Defiance City (Defiance) - 043869',
#  'Delaware City (Delaware) - 043877',
#  'Delphos City (Allen) - 043885',
#  'Dover City (Tuscarawas) - 043893',
#  'Dublin City (Franklin) - 047027',
#  'East Cleveland City School District (Cuyahoga) - 043901',
#  'East Clinton Local (Clinton) - 046409',
#  'East Guernsey Local (Guernsey) - 069682',
#  'East Holmes Local (Holmes) - 047688',
#  'East Knox Local (Knox) - 047845',
#  'East Liverpool City (Columbiana) - 043919',
#  'East Muskingum Local (Muskingum) - 048835',
#  'East Palestine City (Columbiana) - 043927',
#  'Eastern Local (Meigs) - 048512',
#  'Eastern Local School District (Brown) - 046037',
#  'Eastern Local School District (Pike) - 049122',
#  'Eastwood Local (Wood) - 050674',
#  'Eaton Community City (Preble) - 043935',
#  'Edgerton Local (Williams) - 050617',
#  'Edgewood City School District (Butler) - 046094',
#  'Edison Local (Jefferson) - 047795',
#  'Edison Local (formerly Berlin-Milan) (Erie) - 046789',
#  'Edon Northwest Local (Williams) - 050625',
#  'Elgin Local (Marion) - 048413',
#  'Elida Local (Allen) - 045773',
#  'Elmwood Local (Wood) - 050682',
#  'Elyria City Schools (Lorain) - 043943',
#  'Euclid City (Cuyahoga) - 043950',
#  'Evergreen Local (Fulton) - 047050',
#  'Fairbanks Local (Union) - 050328',
#  'Fairborn City (Greene) - 043968',
#  'Fairfield City (Butler) - 046102',
#  'Fairfield Local (Highland) - 047621',
#  'Fairfield Union Local (Fairfield) - 046870',
#  'Fairland Local (Lawrence) - 047936',
#  'Fairlawn Local (Shelby) - 049775',
#  'Fairless Local (Stark) - 049841',
#  'Fairport Harbor Exempted Village (Lake) - 045369',
#  'Fairview Park City (Cuyahoga) - 043976',
#  'Fayette Local (Fulton) - 047068',
#  'Fayetteville-Perry Local (Brown) - 046045',
#  'Federal Hocking Local (Athens) - 045914',
#  'Felicity-Franklin Local (Clermont) - 046334',
#  'Field Local (Portage) - 049197',
#  'Findlay City (Hancock) - 043984',
#  'Finneytown Local (Hamilton) - 047332',
#  'Firelands Local (Lorain) - 048157',
#  'Forest Hills Local (Hamilton) - 047340',
#  'Fort Frye Local (Washington) - 050484',
#  'Fort Loramie Local (Shelby) - 049783',
#  'Fort Recovery Local (Mercer) - 048595',
#  'Fostoria City (Seneca) - 043992',
#  'Franklin City (Warren) - 044008',
#  'Franklin Local (Muskingum) - 048843',
#  'Franklin Monroe Local (Darke) - 046649',
#  'Fredericktown Local (Knox) - 047852',
#  'Fremont City (Sandusky) - 044016',
#  'Frontier Local (Washington) - 050492',
#  'Gahanna-Jefferson City (Franklin) - 046961',
#  'Galion City (Crawford) - 044024',
#  'Gallia County Local (Gallia) - 065680',
#  'Gallipolis City (Gallia) - 044032',
#  'Garaway Local (Tuscarawas) - 050278',
#  'Garfield Heights City Schools (Cuyahoga) - 044040',
#  'Geneva Area City (Ashtabula) - 044057',
#  'Genoa Area Local (Ottawa) - 048942',
#  'Georgetown Exempted Village (Brown) - 045377',
#  'Gibsonburg Exempted Village (Sandusky) - 045385',
#  'Girard City School District (Trumbull) - 044065',
#  'Goshen Local (Clermont) - 046342',
#  'Graham Local (Champaign) - 046193',
#  'Grand Valley Local (Ashtabula) - 045864',
#  'Grandview Heights Schools (Franklin) - 044073',
#  'Granville Exempted Village (Licking) - 045393',
#  'Green Local (Wayne) - 050559',
#  'Green Local (Scioto) - 049619',
#  'Green Local (Summit) - 050013',
#  'Greeneview Local (Greene) - 047266',
#  'Greenfield Exempted Village (Highland) - 045401',
#  'Greenon Local (Clark) - 046235',
#  'Greenville City (Darke) - 044099',
#  'Groveport Madison Local (Franklin) - 046979',
#  'Hamilton City (Butler) - 044107',
#  'Hamilton Local (Franklin) - 046953',
#  'Hardin Northern Local (Hardin) - 047498',
#  'Hardin-Houston Local (Shelby) - 049791',
#  'Harrison Hills City (Harrison) - 045245',
#  'Heath City (Licking) - 044115',
#  'Hicksville Exempted Village School District (Defiance) - 045419',
#  'Highland Local (Morrow) - 048801',
#  'Highland Local (Medina) - 048496',
#  'Hilliard City (Franklin) - 047019',
#  'Hillsboro City (Highland) - 044123',
#  'Hillsdale Local (Ashland) - 045823',
#  'Holgate Local (Henry) - 047571',
#  'Hopewell-Loudon Local (Seneca) - 049700',
#  'Howland Local (Trumbull) - 050161',
#  'Hubbard Exempted Village (Trumbull) - 045427',
#  'Huber Heights City (Montgomery) - 048751',
#  'Hudson City (Summit) - 050021',
#  'Huntington Local (Ross) - 049502',
#  'Huron City Schools (Erie) - 044131',
#  'Independence Local (Cuyahoga) - 046565',
#  'Indian Creek Local (Jefferson) - 047803',
#  'Indian Hill Exempted Village (Hamilton) - 045435',
#  'Indian Lake Local (Logan) - 048082',
#  'Indian Valley Local (Tuscarawas) - 050286',
#  'Ironton City School District (Lawrence) - 044149',
#  'Jackson Center Local (Shelby) - 049809',
#  'Jackson City (Jackson) - 044156',
#  'Jackson Local (Stark) - 049858',
#  'Jackson-Milton Local (Mahoning) - 048322',
#  'James A Garfield Local (Portage) - 049205',
#  'Jefferson Area Local (Ashtabula) - 045872',
#  'Jefferson Local (Madison) - 048256',
#  'Jefferson Township Local (Montgomery) - 048686',
#  'Jennings Local (Putnam) - 049338',
#  'Johnstown-Monroe Local (Licking) - 047985',
#  'Jonathan Alder Local (Madison) - 048264',
#  'Joseph Badger Local (Trumbull) - 050179',
#  'Kalida Local (Putnam) - 049346',
#  'Kelleys Island Local (Erie) - 046797',
#  'Kenston Local (Geauga) - 047191',
#  'Kent City (Portage) - 044164',
#  'Kenton City (Hardin) - 044172',
#  'Kettering City School District (Montgomery) - 044180',
#  'Keystone Local (Lorain) - 048165',
#  'Kings Local (Warren) - 050435',
#  'Kirtland Local (Lake) - 047878',
#  'LaBrae Local (Trumbull) - 050245',
#  'Lake Local (Wood) - 050690',
#  'Lake Local (Stark) - 049866',
#  'Lakeview Local (Trumbull) - 050187',
#  'Lakewood City (Cuyahoga) - 044198',
#  'Lakewood Local (Licking) - 047993',
#  'Lakota Local (Butler) - 046110',
#  'Lakota Local (Sandusky) - 049569',
#  'Lancaster City (Fairfield) - 044206',
#  'Lebanon City (Warren) - 044214',
#  'Leetonia Exempted Village School District (Columbiana) - 045443',
#  'Leipsic Local (Putnam) - 049353',
#  'Lexington Local (Richland) - 049437',
#  'Liberty Center Local (Henry) - 047589',
#  'Liberty Local (Trumbull) - 050195',
#  'Liberty Union-Thurston Local (Fairfield) - 046888',
#  'Liberty-Benton Local (Hancock) - 047449',
#  'Licking Heights Local (Licking) - 048009',
#  'Licking Valley Local (Licking) - 048017',
#  'Lima City (Allen) - 044222',
#  'Lincolnview Local (Van Wert) - 050369',
#  'Lisbon Exempted Village (Columbiana) - 045450',
#  'Little Miami Local (Warren) - 050443',
#  'Lockland Local (Hamilton) - 044230',
#  'Logan Elm Local (Pickaway) - 049080',
#  'Logan-Hocking Local (Hocking) - 044248',
#  'London City (Madison) - 044255',
#  'Lorain City (Lorain) - 044263',
#  'Lordstown Local (Trumbull) - 050203',
#  'Loudonville-Perrysville Exempted Village (Ashland) - 045468',
#  'Louisville City (Stark) - 049874',
#  'Loveland City (Hamilton) - 044271',
#  'Lowellville Local (Mahoning) - 048330',
#  'Lucas Local (Richland) - 049445',
#  'Lynchburg-Clay Local (Highland) - 047639',
#  'Mad River Local (Montgomery) - 048702',
#  'Madeira City (Hamilton) - 044289',
#  'Madison Local (Butler) - 046128',
#  'Madison Local (Lake) - 047886',
#  'Madison Local (Richland) - 049452',
#  'Madison-Plains Local (Madison) - 048272',
#  'Manchester Local (Adams) - 000442',
#  'Manchester Local (Summit) - 050005',
#  'Mansfield City (Richland) - 044297',
#  'Maple Heights City (Cuyahoga) - 044305',
#  'Mapleton Local (Ashland) - 045831',
#  'Maplewood Local (Trumbull) - 050211',
#  'Margaretta Local (Erie) - 046805',
#  'Mariemont City (Hamilton) - 044313',
#  'Marietta City (Washington) - 044321',
#  'Marion City (Marion) - 044339',
#  'Marion Local (Mercer) - 048553',
#  'Marlington Local (Stark) - 049882',
#  'Martins Ferry City (Belmont) - 044347',
#  'Marysville Exempted Village (Union) - 045476',
#  'Mason City (Warren) - 050450',
#  'Massillon City (Stark) - 044354',
#  'Mathews Local (Trumbull) - 050153',
#  'Maumee City (Lucas) - 044362',
#  'Mayfield City (Cuyahoga) - 044370',
#  'Maysville Local (Muskingum) - 048850',
#  'McComb Local (Hancock) - 047456',
#  'McDonald Local (Trumbull) - 050229',
#  'Mechanicsburg Exempted Village (Champaign) - 045484',
#  'Medina City SD (Medina) - 044388',
#  'Meigs Local (Meigs) - 048520',
#  'Mentor Exempted Village (Lake) - 045492',
#  'Miami East Local (Miami) - 048629',
#  'Miami Trace Local (Fayette) - 046920',
#  'Miamisburg City (Montgomery) - 044396',
#  'Middle Bass Local (Ottawa) - 048959',
#  'Middletown City (Butler) - 044404',
#  'Midview Local (Lorain) - 048173',
#  'Milford Exempted Village (Clermont) - 045500',
#  'Millcreek-West Unity Local (Williams) - 050633',
#  'Miller City-New Cleveland Local (Putnam) - 049361',
#  'Milton-Union Exempted Village (Miami) - 045518',
#  'Minerva Local (Stark) - 049890',
#  'Minford Local (Scioto) - 049627',
#  'Minster Local (Auglaize) - 045948',
#  'Mississinawa Valley Local (Darke) - 046672',
#  'Mogadore Local (Summit) - 050039',
#  'Mohawk Local (Wyandot) - 050740',
#  'Monroe Local (Butler) - 139303',
#  'Monroeville Local (Huron) - 047712',
#  'Montpelier Exempted Village (Williams) - 045526',
#  'Morgan Local (Morgan) - 048777',
#  'Mount Gilead Exempted Village (Morrow) - 045534',
#  'Mount Vernon City (Knox) - 044420',
#  'Mt Healthy City (Hamilton) - 044412',
#  'Napoleon Area City (Henry) - 044438',
#  'National Trail Local (Preble) - 049270',
#  'Nelsonville-York City (Athens) - 044446',
#  'New Albany-Plain Local (Franklin) - 046995',
#  'New Boston Local (Scioto) - 044461',
#  'New Bremen Local (Auglaize) - 045955',
#  'New Knoxville Local (Auglaize) - 045963',
#  'New Lebanon Local School District (Montgomery) - 048710',
#  'New Lexington School District (Perry) - 044479',
#  'New London Local (Huron) - 047720',
#  'New Miami Local (Butler) - 046136',
#  'New Philadelphia City (Tuscarawas) - 044487',
#  'New Richmond Exempted Village (Clermont) - 045559',
#  'New Riegel Local (Seneca) - 049718',
#  'Newark City (Licking) - 044453',
#  'Newcomerstown Exempted Village (Tuscarawas) - 045542',
#  'Newton Falls Exempted Village (Trumbull) - 045567',
#  'Newton Local (Miami) - 048637',
#  'Niles City (Trumbull) - 044495',
#  'Noble Local (Noble) - 048900',
#  'Nordonia Hills City (Summit) - 050047',
#  'North Baltimore Local (Wood) - 050708',
#  'North Bass Local (Ottawa) - 048967',
#  'North Canton City (Stark) - 044503',
#  'North Central Local (Williams) - 050641',
#  'North College Hill City (Hamilton) - 044511',
#  'North Fork Local (Licking) - 048025',
#  'North Olmsted City (Cuyahoga) - 044529',
#  'North Ridgeville City (Lorain) - 044537',
#  'North Royalton City (Cuyahoga) - 044545',
#  'North Union Local School District (Union) - 050336',
#  'Northeastern Local (Clark) - 046250',
#  'Northeastern Local (Defiance) - 046722',
#  'Northern Local (Perry) - 049056',
#  'Northmont City (Montgomery) - 048728',
#  'Northmor Local (Morrow) - 048819',
#  'Northridge Local (Montgomery) - 048736',
#  'Northridge Local (Licking) - 048033',
#  'Northwest Local (Stark) - 049908',
#  'Northwest Local (Hamilton) - 047365',
#  'Northwest Local (Scioto) - 049635',
#  'Northwestern Local (Clark) - 046268',
#  'Northwestern Local (Wayne) - 050575',
#  'Northwood Local Schools (Wood) - 050716',
#  'Norton City (Summit) - 044552',
#  'Norwalk City (Huron) - 044560',
#  'Norwayne Local (Wayne) - 050567',
#  'Norwood City (Hamilton) - 044578',
#  'Oak Hill Union Local (Jackson) - 047761',
#  'Oak Hills Local (Hamilton) - 047373',
#  'Oakwood City (Montgomery) - 044586',
#  'Oberlin City Schools (Lorain) - 044594',
#  'Old Fort Local (Seneca) - 049726',
#  'Olentangy Local (Delaware) - 046763',
#  'Olmsted Falls City (Cuyahoga) - 046573',
#  'Ontario Local (Richland) - 049478',
#  'Orange City (Cuyahoga) - 046581',
#  'Oregon City (Lucas) - 044602',
#  'Orrville City (Wayne) - 044610',
#  'Osnaburg Local (Stark) - 049916',
#  'Otsego Local (Wood) - 050724',
#  'Ottawa Hills Local (Lucas) - 048215',
#  'Ottawa-Glandorf Local (Putnam) - 049379',
#  'Ottoville Local (Putnam) - 049387',
#  'Painesville City Local (Lake) - 044628',
#  'Paint Valley Local (Ross) - 049510',
#  'Pandora-Gilboa Local (Putnam) - 049395',
#  'Parkway Local (Mercer) - 048579',
#  'Parma City (Cuyahoga) - 044636',
#  'Patrick Henry Local (Henry) - 047597',
#  'Paulding Exempted Village (Paulding) - 045575',
#  'Perkins Local (Erie) - 046813',
#  'Perry Local (Allen) - 045781',
#  'Perry Local (Stark) - 049924',
#  'Perry Local (Lake) - 047902',
#  'Perrysburg Exempted Village (Wood) - 045583',
#  'Pettisville Local (Fulton) - 047076',
#  'Pickerington Local (Fairfield) - 046896',
#  'Pike-Delta-York Local (Fulton) - 047084',
#  'Piqua City (Miami) - 044644',
#  'Plain Local (Stark) - 049932',
#  'Pleasant Local (Marion) - 048421',
#  'Plymouth-Shiloh Local (Richland) - 049460',
#  'Poland Local (Mahoning) - 048348',
#  'Port Clinton City (Ottawa) - 044651',
#  'Portsmouth City (Scioto) - 044669',
#  'Preble Shawnee Local (Preble) - 049288',
#  'Princeton City (Hamilton) - 044677',
#  'Put-In-Bay Local (Ottawa) - 048975',
#  'Pymatuning Valley Local (Ashtabula) - 045880',
#  'Ravenna City (Portage) - 044685',
#  'Reading Community City (Hamilton) - 044693',
#  'Revere Local (Summit) - 050054',
#  'Reynoldsburg City (Franklin) - 047001',
#  'Richmond Heights Local (Cuyahoga) - 046599',
#  'Ridgedale Local (Marion) - 048439',
#  'Ridgemont Local (Hardin) - 047506',
#  'Ridgewood Local (Coshocton) - 046474',
#  'Ripley-Union-Lewis-Huntington Local (Brown) - 046078',
#  'Rittman Exempted Village (Wayne) - 045591',
#  'River Valley Local (Marion) - 048447',
#  'River View Local (Coshocton) - 046482',
#  'Riverdale Local (Hancock) - 047514',
#  'Riverside Local (Logan) - 048090',
#  'Riverside Local (Lake) - 047894',
#  'Rock Hill Local (Lawrence) - 047944',
#  'Rocky River City (Cuyahoga) - 044701',
#  'Rolling Hills Local (Guernsey) - 047308',
#  'Rootstown Local (Portage) - 049213',
#  'Ross Local (Butler) - 046144',
#  'Rossford Exempted Village (Wood) - 045609',
#  'Russia Local (Shelby) - 049817',
#  'Salem City (Columbiana) - 044735',
#  'Sandusky City (Erie) - 044743',
#  'Sandy Valley Local (Stark) - 049940',
#  'Scioto Valley Local (Pike) - 049130',
#  'Sebring Local (Mahoning) - 048355',
#  'Seneca East Local (Seneca) - 049684',
#  'Shadyside Local (Belmont) - 046003',
#  'Shaker Heights City (Cuyahoga) - 044750',
#  'Shawnee Local (Allen) - 045799',
#  'Sheffield-Sheffield Lake City (Lorain) - 044768',
#  'Shelby City (Richland) - 044776',
#  'Sidney City (Shelby) - 044784',
#  'Solon City (Cuyahoga) - 046607',
#  'South Central Local (Huron) - 047738',
#  'South Euclid-Lyndhurst City (Cuyahoga) - 044792',
#  'South Point Local (Lawrence) - 047951',
#  'South Range Local (Mahoning) - 048363',
#  'South-Western City (Franklin) - 044800',
#  'Southeast Local (Wayne) - 050583',
#  'Southeast Local (Portage) - 049221',
#  'Southeastern Local (Ross) - 049528',
#  'Southeastern Local (Clark) - 046276',
#  'Southern Local (Perry) - 049064',
#  'Southern Local (Meigs) - 048538',
#  'Southern Local (Columbiana) - 046441',
#  'Southington Local (Trumbull) - 050237',
#  'Southwest Licking Local (Licking) - 048041',
#  'Southwest Local (Hamilton) - 047381',
#  'Spencerville Local (Allen) - 045807',
#  'Springboro Community City (Warren) - 050427',
#  'Springfield City School District (Clark) - 044818',
#  'Springfield Local (Summit) - 050062',
#  'Springfield Local (Lucas) - 048223',
#  'Springfield Local (Mahoning) - 048371',
#  'St Bernard-Elmwood Place City (Hamilton) - 044719',
#  'St Clairsville-Richland City (Belmont) - 045997',
#  'St Henry Consolidated Local (Mercer) - 048587',
#  'St Marys City (Auglaize) - 044727',
#  'Steubenville City (Jefferson) - 044826',
#  'Stow-Munroe Falls City School District (Summit) - 044834',
#  'Strasburg-Franklin Local (Tuscarawas) - 050294',
#  'Streetsboro City (Portage) - 049239',
#  'Strongsville City (Cuyahoga) - 044842',
#  'Struthers City (Mahoning) - 044859',
#  'Stryker Local (Williams) - 050658',
#  'Swanton Local (Fulton) - 047092',
#  'Switzerland of Ohio Local (Monroe) - 048652',
#  'Sycamore Community City (Hamilton) - 044867',
#  'Sylvania Schools (Lucas) - 044875',
#  'Symmes Valley Local (Lawrence) - 047969',
#  'Talawanda City (Butler) - 046151',
#  'Tallmadge City (Summit) - 044883',
#  'Teays Valley Local (Pickaway) - 049098',
#  'Tecumseh Local (Clark) - 046243',
#  'Three Rivers Local (Hamilton) - 047399',
#  'Tiffin City (Seneca) - 044891',
#  'Tipp City Exempted Village (Miami) - 045617',
#  'Toledo City (Lucas) - 044909',
#  'Toronto City (Jefferson) - 044917',
#  'Tri-County North Local (Preble) - 091397',
#  'Tri-Valley Local (Muskingum) - 048876',
#  'Tri-Village Local (Darke) - 046680',
#  'Triad Local (Champaign) - 046201',
#  'Trimble Local (Athens) - 045922',
#  'Triway Local (Wayne) - 050591',
#  'Trotwood-Madison City (Montgomery) - 048694',
#  'Troy City (Miami) - 044925',
#  'Tuscarawas Valley Local (Tuscarawas) - 050302',
#  'Tuslaw Local (Stark) - 049957',
#  'Twin Valley Community Local (Preble) - 049296',
#  'Twinsburg City (Summit) - 050070',
#  'Union Local (Belmont) - 046011',
#  'Union-Scioto Local (Ross) - 049536',
#  'United Local (Columbiana) - 046458',
#  'Upper Arlington City (Franklin) - 044933',
#  'Upper Sandusky Exempted Village (Wyandot) - 045625',
#  'Upper Scioto Valley Local (Hardin) - 047522',
#  'Urbana City (Champaign) - 044941',
#  'Valley Local (Scioto) - 049643',
#  'Valley View Local (Montgomery) - 048744',
#  'Van Buren Local (Hancock) - 047464',
#  'Van Wert City (Van Wert) - 044966',
#  'Vandalia-Butler City (Montgomery) - 044958',
#  'Vanlue Local (Hancock) - 047472',
#  'Vermilion Local (Erie) - 046821',
#  'Versailles Exempted Village (Darke) - 045633',
#  'Vinton County Local (Vinton) - 050393',
#  'Wadsworth City (Medina) - 044974',
#  'Walnut Township Local (Fairfield) - 046904',
#  'Wapakoneta City (Auglaize) - 044982',
#  'Warren City (Trumbull) - 044990',
#  'Warren Local (Washington) - 050500',
#  'Warrensville Heights City (Cuyahoga) - 045005',
#  'Washington Court House City (Fayette) - 045013',
#  'Washington Local (Lucas) - 048231',
#  'Washington-Nile Local (Scioto) - 049650',
#  'Waterloo Local (Portage) - 049247',
#  'Wauseon Exempted Village (Fulton) - 045641',
#  'Waverly City (Pike) - 049148',
#  'Wayne Local (Warren) - 050468',
#  'Wayne Trace Local (Paulding) - 049031',
#  'Waynesfield-Goshen Local (Auglaize) - 045971',
#  'Weathersfield Local (Trumbull) - 050252',
#  'Wellington Exempted Village (Lorain) - 045658',
#  'Wellston City (Jackson) - 045021',
#  'Wellsville Local (Columbiana) - 045039',
#  'West Branch Local (Mahoning) - 048389',
#  'West Carrollton City (Montgomery) - 045054',
#  'West Clermont Local (Clermont) - 046359',
#  'West Geauga Local (Geauga) - 047225',
#  'West Holmes Local (Holmes) - 047696',
#  'West Liberty-Salem Local (Champaign) - 046219',
#  'West Muskingum Local (Muskingum) - 048884',
#  'Western Brown Local (Brown) - 046060',
#  'Western Local (Pike) - 049155',
#  'Western Reserve Local (Huron) - 047746',
#  'Western Reserve Local (Mahoning) - 048397',
#  'Westerville City (Franklin) - 045047',
#  'Westfall Local (Pickaway) - 049106',
#  'Westlake City (Cuyahoga) - 045062',
#  'Wheelersburg Local (Scioto) - 049668',
#  'Whitehall City (Franklin) - 045070',
#  'Wickliffe City (Lake) - 045088',
#  'Willard City (Huron) - 045096',
#  'Williamsburg Local (Clermont) - 046367',
#  'Willoughby-Eastlake City (Lake) - 045104',
#  'Wilmington City (Clinton) - 045112',
#  'Windham Exempted Village (Portage) - 045666',
#  'Winton Woods City (Hamilton) - 044081',
#  'Wolf Creek Local (Washington) - 050518',
#  'Woodmore Local (Sandusky) - 049577',
#  'Woodridge Local (Summit) - 049973',
#  'Wooster City (Wayne) - 045120',
#  'Worthington City (Franklin) - 045138',
#  'Wynford Local (Crawford) - 046524',
#  'Wyoming City (Hamilton) - 045146',
#  'Xenia Community City (Greene) - 045153',
#  'Yellow Springs Exempted Village (Greene) - 045674',
#  'Youngstown City (Mahoning) - 045161',
#  'Zane Trace Local (Ross) - 049544',
#  'Zanesville City (Muskingum) - 045179']

# %%
#set chromodriver.exe path
driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")
driver.implicitly_wait(0.5)

#first one is total 
for i in range(74, len(list_school_names)): 
    print(list_school_names[i] + " " + str(i))
    time.sleep(1)
    url = "https://reports.education.ohio.gov/finance/legacy-report" 
    driver.get(url)
    driver.implicitly_wait(10)
    time.sleep(3)

    ## scrape 2000
    YEAR = year
    FINAL = final_val
    #first step, fill in info, press go 

    # fill in LEA type 
    text_box_path = '/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input'
    text_box = driver.find_element(By.XPATH, text_box_path)
    text_box.send_keys("Traditional School District")

    text_box_selection_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div"
    time.sleep(.25)
    drop_box_1 = driver.find_element(By.XPATH, text_box_selection_path)
    time.sleep(.25)
    drop_box_1.click()

    #fill in year 
    year_text_box_path ="/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[2]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    year_text_box = driver.find_element(By.XPATH, year_text_box_path)
    year_text_box.send_keys(YEAR)

    year_drop_select ="/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[2]/ul/li[2]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"
    time.sleep(.25)
    drop_box_2 = driver.find_element(By.XPATH, year_drop_select)
    time.sleep(.25)
    drop_box_2.click()

    time.sleep(.25)
    go_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[3]/button"
    time.sleep(.25)
    go_button = driver.find_element(By.XPATH, go_path)
    time.sleep(.25)

    go_button_bool = None
    while not go_button_bool:
        try:
            go_button.click()
            go_button_bool=1
        except ElementClickInterceptedException:
            print('********** wait element click error **********')
            time.sleep(2)


    time.sleep(.25)
    #next step 

    payment_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[3]/div/ul/li/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    payment_path_box = driver.find_element(By.XPATH, payment_path)
    time.sleep(.25)

    payment_path_box.send_keys(FINAL)
    payment_path_selection_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[3]/div/ul/li/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"

    time.sleep(.25)
    drop_box_3 = driver.find_element(By.XPATH, payment_path_selection_path)
    drop_box_3.click()

    #next step is to find all LEA values 

    lea_box_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    lea_arrow_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div"

    #click on arrow to show options 
    driver.find_element(By.XPATH, lea_arrow_path).click()

    time.sleep(.25)
    drop_down_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div"
    drop_down= driver.find_element(By.XPATH, drop_down_path)

    drop_down_school_district_path= "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    drop_down_school_district= driver.find_element(By.XPATH, drop_down_school_district_path)
    just_name =list_school_names[i].split("(")[0].strip()
    #try doing by key. 
    IRA_i = list_school_names[i].split()[-1]
    drop_down_school_district.send_keys(IRA_i) #list_school_names[i])

    school_district_select_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"

    drop_box_4 = driver.find_element(By.XPATH, school_district_select_path)

    drop_button_bool = None
    while not drop_button_bool:
        try:
            drop_box_4 = driver.find_element(By.XPATH, school_district_select_path)
            drop_button_bool=1
        except NoSuchElementException:
            time.sleep(2)


    #except NoSuchElementException: 
    #    drop_down_school_district_path= "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    #    drop_down_school_district= driver.find_element(By.XPATH, drop_down_school_district_path)
    #    just_name =list_school_names[i].split("(")[0].strip()
    #    drop_down_school_district.send_keys(just_name)
    #    drop_box_4 = driver.find_element(By.XPATH, school_district_select_path)

    drop_box_4.click()

    time.sleep(.25)
    #click process button! 
    process_button_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[3]/ul/li[2]/button"
    driver.find_element(By.XPATH, process_button_path).click()
    time.sleep(2)

    ## new code here     

    
    page_bool = None
    while not page_bool:
        try:
            driver.implicitly_wait(3)
            testing_web_text= driver.page_source
            page_bool=1
        except IndexError:
            print('********** wait index error **********')
            url = "https://reports.education.ohio.gov/finance/legacy-report" 
            time.sleep(2)
            
       
    IRA_i = list_school_names[i].split()[-1]
    county_i= list_school_names[i].split("(")[1].split()[0].split(")")[0]
    

    if testing_web_text.find("District Breakdown") == -1: #DISTRICT BREAKDOWN (2014)
        list_i = [IRA_i, YEAR, county_i] + ['N/A'] *(len(colnames)-3)
        print("**** no data ****")
  
    else: 
        testing_web_text= driver.page_source
        main= testing_web_text.split("District Breakdown")[-1]
        main= main.split("IRN: All")[1]
        total_student_fte= main.split("Total Student FTE:")[1].split()[0]

        CS_ADM_sped_total_cat1= main.split("Category 1 Special Education FTE:")[1].split()[0]
        CS_ADM_sped_total_cat2= main.split("Category 2 Special Education FTE:")[1].split()[0]
        CS_ADM_sped_total_cat3= main.split("Category 3 Special Education FTE:")[1].split()[0]
        CS_ADM_sped_total_cat4= main.split("Category 4 Special Education FTE:")[1].split()[0]
        CS_ADM_sped_total_cat5= main.split("Category 5 Special Education FTE:")[1].split()[0]
        CS_ADM_sped_total_cat6= main.split("Category 6 Special Education FTE:")[1].split()[0]

        CS_CTA_cat1_FTE= main.split("Category 1 Career Tech FTE:")[1].split()[0]
        CS_CTA_cat2_FTE= main.split("Category 2 Career Tech FTE:")[1].split()[0]
        CS_CTA_cat3_FTE= main.split("Category 3 Career Tech FTE:")[1].split()[0]
        CS_CTA_cat4_FTE= main.split("Category 4 Career Tech FTE:")[1].split()[0]
        CS_CTA_cat5_FTE= main.split("Category 5 Career Tech FTE:")[1].split()[0]

        CS_INT_1= main.split("Category 1 LEP FTE:")[1].split()[0]
        CS_INT_2= main.split("Category 2 LEP FTE:")[1].split()[0]
        CS_INT_3= main.split("Category 3 LEP FTE:")[1].split()[0]

        CS_econ_dis_FTE= main.split("Economic Disadvantaged FTE:")[1].split()[0]
        econ_dis_index= main.split("District's Economically Disadvantaged Index:")[1].split()[0]

        CS_formula_amt= main.split("Opportunity Grant")[1].split("\n")[0].split()[-1]
        CS_econ_disadv_funded= main.split("Economic Disadvantaged Funding")[1].split("\n")[0].split()[-1]
        CS_LEP_AID = main.split("Limited English Proficiency Funding")[1].split("\n")[0].split()[-1]

        CS_sped_wtd_funds =main.split("Special Education Additional Funding")[1].split("\n")[0].split()[-1]
        CS_CTA_total_funds= main.split("Career Tech Education Funding")[1].split("\n")[0].split()[-1]
        CS_TRANS_AID= main.split("Transportation Funding:")[1].split()[0]
        CS_TOTAL_DEDUCT= main.split("Total Deduction Amounts")[1].split("\n")[0].split()[-1]

        list_i = [IRA_i, YEAR, county_i, 
                  CS_ADM_sped_total_cat1, CS_ADM_sped_total_cat2, CS_ADM_sped_total_cat3, CS_ADM_sped_total_cat4, CS_ADM_sped_total_cat5, CS_ADM_sped_total_cat6,
                  CS_CTA_cat1_FTE, CS_CTA_cat2_FTE, CS_CTA_cat3_FTE, CS_CTA_cat4_FTE, CS_CTA_cat5_FTE, 
                  CS_INT_1,  CS_INT_2, CS_INT_3,
                  CS_econ_dis_FTE, econ_dis_index, 
                  CS_formula_amt, CS_econ_disadv_funded, CS_LEP_AID, 
                  CS_sped_wtd_funds, CS_CTA_total_funds, CS_TRANS_AID, CS_TOTAL_DEDUCT
                   ]
    df.loc[len(df)] = list_i
    #list_list= list_list.append(list_i)

df.to_csv("Community_" + str(year) + ".csv")
# Out:
# /var/folders/09/l3m63nj90fg1l2jshjp_hd5w0000gn/T/ipykernel_22777/1958702138.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")
# Bucyrus City (Crawford) - 043687 74
# Caldwell Exempted Village (Noble) - 045252 75
# Cambridge City (Guernsey) - 043695 76
# Campbell City (Mahoning) - 043703 77
# Canal Winchester Local (Franklin) - 046946 78
# Canfield Local (Mahoning) - 048314 79
# Canton City (Stark) - 043711 80
# Canton Local (Stark) - 049833 81
# Cardinal Local (Geauga) - 047175 82
# Cardington-Lincoln Local (Morrow) - 048793 83
# Carey Exempted Village Schools (Wyandot) - 045260 84
# Carlisle Local (Warren) - 050419 85
# Carrollton Exempted Village (Carroll) - 045278 86
# Cedar Cliff Local (Greene) - 047258 87
# Celina City (Mercer) - 043729 88
# Centerburg Local (Knox) - 047829 89
# Centerville City (Montgomery) - 043737 90
# Central Local (Defiance) - 046714 91
# Chagrin Falls Exempted Village (Cuyahoga) - 045286 92
# Champion Local (Trumbull) - 050138 93
# Chardon Local (Geauga) - 047183 94
# Chesapeake Union Exempted Village (Lawrence) - 045294 95
# Chillicothe City (Ross) - 043745 96
# Chippewa Local (Wayne) - 050534 97
# Cincinnati Public Schools (Hamilton) - 043752 98
# Circleville City (Pickaway) - 043760 99
# Clark-Shawnee Local (Clark) - 046284 100
# Clay Local (Scioto) - 049601 101
# Claymont City (Tuscarawas) - 043778 102
# Clear Fork Valley Local (Richland) - 049411 103
# Clearview Local (Lorain) - 048132 104
# Clermont Northeastern Local (Clermont) - 046326 105
# Cleveland Heights-University Heights City (Cuyahoga) - 043794 106
# Cleveland Municipal (Cuyahoga) - 043786 107
# **** no data ****
# Clinton-Massie Local (Clinton) - 046391 108
# Cloverleaf Local (Medina) - 048488 109
# Clyde-Green Springs Exempted Village (Sandusky) - 045302 110
# Coldwater Exempted Village (Mercer) - 045310 111
# College Corner Local (Preble) - 064964 112
# Colonel Crawford Local (Crawford) - 046516 113
# Columbia Local (Lorain) - 048140 114
# Columbiana Exempted Village (Columbiana) - 045328 115
# Columbus City Schools District (Franklin) - 043802 116
# **** no data ****
# Columbus Grove Local (Putnam) - 049312 117
# Conneaut Area City (Ashtabula) - 043810 118
# Conotton Valley Union Local (Harrison) - 047548 119
# Continental Local (Putnam) - 049320 120
# Copley-Fairlawn City (Summit) - 049981 121
# Cory-Rawson Local (Hancock) - 047431 122
# Coshocton City (Coshocton) - 043828 123
# Coventry Local (Summit) - 049999 124
# Covington Exempted Village (Miami) - 045336 125
# Crestline Exempted Village (Crawford) - 045344 126
# Crestview Local (Columbiana) - 046433 127
# Crestview Local (Richland) - 049429 128
# Crestview Local (Van Wert) - 050351 129
# Crestwood Local (Portage) - 049189 130
# Crooksville Exempted Village (Perry) - 045351 131
# **** no data ****
# Cuyahoga Falls City (Summit) - 043836 132
# Cuyahoga Heights Local (Cuyahoga) - 046557 133
# Dalton Local (Wayne) - 050542 134
# Danbury Local (Ottawa) - 048934 135
# Danville Local (Knox) - 047837 136
# Dawson-Bryant Local (Lawrence) - 047928 137
# Dayton City (Montgomery) - 043844 138
# Deer Park Community City (Hamilton) - 043851 139
# Defiance City (Defiance) - 043869 140
# Delaware City (Delaware) - 043877 141
# Delphos City (Allen) - 043885 142
# Dover City (Tuscarawas) - 043893 143
# Dublin City (Franklin) - 047027 144
# East Cleveland City School District (Cuyahoga) - 043901 145
# East Clinton Local (Clinton) - 046409 146
# East Guernsey Local (Guernsey) - 069682 147
# East Holmes Local (Holmes) - 047688 148
# East Knox Local (Knox) - 047845 149
# East Liverpool City (Columbiana) - 043919 150
# East Muskingum Local (Muskingum) - 048835 151
# East Palestine City (Columbiana) - 043927 152
# Eastern Local (Meigs) - 048512 153
# Eastern Local School District (Brown) - 046037 154
# Eastern Local School District (Pike) - 049122 155
# Eastwood Local (Wood) - 050674 156
# Eaton Community City (Preble) - 043935 157
# Edgerton Local (Williams) - 050617 158
# Edgewood City School District (Butler) - 046094 159
# Edison Local (Jefferson) - 047795 160
# Edison Local (formerly Berlin-Milan) (Erie) - 046789 161
# Edon Northwest Local (Williams) - 050625 162
# Elgin Local (Marion) - 048413 163
# Elida Local (Allen) - 045773 164
# Elmwood Local (Wood) - 050682 165
# Elyria City Schools (Lorain) - 043943 166
# Euclid City (Cuyahoga) - 043950 167
# Evergreen Local (Fulton) - 047050 168
# Fairbanks Local (Union) - 050328 169
# Fairborn City (Greene) - 043968 170
# Fairfield City (Butler) - 046102 171
# Fairfield Local (Highland) - 047621 172
# Fairfield Union Local (Fairfield) - 046870 173
# Fairland Local (Lawrence) - 047936 174
# Fairlawn Local (Shelby) - 049775 175
# Fairless Local (Stark) - 049841 176
# Fairport Harbor Exempted Village (Lake) - 045369 177
# Fairview Park City (Cuyahoga) - 043976 178
# Fayette Local (Fulton) - 047068 179
# Fayetteville-Perry Local (Brown) - 046045 180
# Federal Hocking Local (Athens) - 045914 181
# Felicity-Franklin Local (Clermont) - 046334 182
# Field Local (Portage) - 049197 183
# Findlay City (Hancock) - 043984 184
# Finneytown Local (Hamilton) - 047332 185
# Firelands Local (Lorain) - 048157 186
# Forest Hills Local (Hamilton) - 047340 187
# Fort Frye Local (Washington) - 050484 188
# Fort Loramie Local (Shelby) - 049783 189
# Fort Recovery Local (Mercer) - 048595 190
# **** no data ****
# Fostoria City (Seneca) - 043992 191
# Franklin City (Warren) - 044008 192
# Franklin Local (Muskingum) - 048843 193
# Franklin Monroe Local (Darke) - 046649 194
# Fredericktown Local (Knox) - 047852 195
# Fremont City (Sandusky) - 044016 196
# Frontier Local (Washington) - 050492 197
# Gahanna-Jefferson City (Franklin) - 046961 198
# Galion City (Crawford) - 044024 199
# Gallia County Local (Gallia) - 065680 200
# Gallipolis City (Gallia) - 044032 201
# Garaway Local (Tuscarawas) - 050278 202
# Garfield Heights City Schools (Cuyahoga) - 044040 203
# **** no data ****
# Geneva Area City (Ashtabula) - 044057 204
# **** no data ****
# Genoa Area Local (Ottawa) - 048942 205
# Georgetown Exempted Village (Brown) - 045377 206
# Gibsonburg Exempted Village (Sandusky) - 045385 207
# Girard City School District (Trumbull) - 044065 208
# Goshen Local (Clermont) - 046342 209
# Graham Local (Champaign) - 046193 210
# Grand Valley Local (Ashtabula) - 045864 211
# Grandview Heights Schools (Franklin) - 044073 212
# Granville Exempted Village (Licking) - 045393 213
# Green Local (Wayne) - 050559 214
# Green Local (Scioto) - 049619 215
# Green Local (Summit) - 050013 216
# Greeneview Local (Greene) - 047266 217
# Greenfield Exempted Village (Highland) - 045401 218
# Greenon Local (Clark) - 046235 219
# Greenville City (Darke) - 044099 220
# Groveport Madison Local (Franklin) - 046979 221
# Hamilton City (Butler) - 044107 222
# Hamilton Local (Franklin) - 046953 223
# Hardin Northern Local (Hardin) - 047498 224
# Hardin-Houston Local (Shelby) - 049791 225
# Harrison Hills City (Harrison) - 045245 226
# Heath City (Licking) - 044115 227
# Hicksville Exempted Village School District (Defiance) - 045419 228
# Highland Local (Morrow) - 048801 229
# Highland Local (Medina) - 048496 230
# Hilliard City (Franklin) - 047019 231
# Hillsboro City (Highland) - 044123 232
# Hillsdale Local (Ashland) - 045823 233
# Holgate Local (Henry) - 047571 234
# Hopewell-Loudon Local (Seneca) - 049700 235
# Howland Local (Trumbull) - 050161 236
# Hubbard Exempted Village (Trumbull) - 045427 237
# Huber Heights City (Montgomery) - 048751 238
# Hudson City (Summit) - 050021 239
# Huntington Local (Ross) - 049502 240
# Huron City Schools (Erie) - 044131 241
# Independence Local (Cuyahoga) - 046565 242
# Indian Creek Local (Jefferson) - 047803 243
# Indian Hill Exempted Village (Hamilton) - 045435 244
# Indian Lake Local (Logan) - 048082 245
# Indian Valley Local (Tuscarawas) - 050286 246
# Ironton City School District (Lawrence) - 044149 247
# Jackson Center Local (Shelby) - 049809 248
# Jackson City (Jackson) - 044156 249
# Jackson Local (Stark) - 049858 250
# Jackson-Milton Local (Mahoning) - 048322 251
# James A Garfield Local (Portage) - 049205 252
# Jefferson Area Local (Ashtabula) - 045872 253
# Jefferson Local (Madison) - 048256 254
# Jefferson Township Local (Montgomery) - 048686 255
# Jennings Local (Putnam) - 049338 256
# Johnstown-Monroe Local (Licking) - 047985 257
# Jonathan Alder Local (Madison) - 048264 258
# Joseph Badger Local (Trumbull) - 050179 259
# Kalida Local (Putnam) - 049346 260
# Kelleys Island Local (Erie) - 046797 261
# **** no data ****
# Kenston Local (Geauga) - 047191 262
# Kent City (Portage) - 044164 263
# Kenton City (Hardin) - 044172 264
# Kettering City School District (Montgomery) - 044180 265
# Keystone Local (Lorain) - 048165 266
# Kings Local (Warren) - 050435 267
# Kirtland Local (Lake) - 047878 268
# LaBrae Local (Trumbull) - 050245 269
# Lake Local (Wood) - 050690 270
# Lake Local (Stark) - 049866 271
# Lakeview Local (Trumbull) - 050187 272
# Lakewood City (Cuyahoga) - 044198 273
# Lakewood Local (Licking) - 047993 274
# Lakota Local (Butler) - 046110 275
# Lakota Local (Sandusky) - 049569 276
# Lancaster City (Fairfield) - 044206 277
# Lebanon City (Warren) - 044214 278
# Leetonia Exempted Village School District (Columbiana) - 045443 279
# Leipsic Local (Putnam) - 049353 280
# Lexington Local (Richland) - 049437 281
# Liberty Center Local (Henry) - 047589 282
# Liberty Local (Trumbull) - 050195 283
# Liberty Union-Thurston Local (Fairfield) - 046888 284
# Liberty-Benton Local (Hancock) - 047449 285
# Licking Heights Local (Licking) - 048009 286
# Licking Valley Local (Licking) - 048017 287
# Lima City (Allen) - 044222 288
# Lincolnview Local (Van Wert) - 050369 289
# Lisbon Exempted Village (Columbiana) - 045450 290
# Little Miami Local (Warren) - 050443 291
# Lockland Local (Hamilton) - 044230 292
# Logan Elm Local (Pickaway) - 049080 293
# Logan-Hocking Local (Hocking) - 044248 294
# London City (Madison) - 044255 295
# Lorain City (Lorain) - 044263 296
# Lordstown Local (Trumbull) - 050203 297
# Loudonville-Perrysville Exempted Village (Ashland) - 045468 298
# Louisville City (Stark) - 049874 299
# Loveland City (Hamilton) - 044271 300
# Lowellville Local (Mahoning) - 048330 301
# Lucas Local (Richland) - 049445 302
# Lynchburg-Clay Local (Highland) - 047639 303
# Mad River Local (Montgomery) - 048702 304
# Madeira City (Hamilton) - 044289 305
# Madison Local (Butler) - 046128 306
# Madison Local (Lake) - 047886 307
# Madison Local (Richland) - 049452 308
# Madison-Plains Local (Madison) - 048272 309
# Manchester Local (Adams) - 000442 310
# Manchester Local (Summit) - 050005 311
# Mansfield City (Richland) - 044297 312
# Maple Heights City (Cuyahoga) - 044305 313
# Mapleton Local (Ashland) - 045831 314
# Maplewood Local (Trumbull) - 050211 315
# Margaretta Local (Erie) - 046805 316
# Mariemont City (Hamilton) - 044313 317
# Marietta City (Washington) - 044321 318
# Marion City (Marion) - 044339 319
# Marion Local (Mercer) - 048553 320
# Marlington Local (Stark) - 049882 321
# Martins Ferry City (Belmont) - 044347 322
# Marysville Exempted Village (Union) - 045476 323
# Mason City (Warren) - 050450 324
# Massillon City (Stark) - 044354 325
# Mathews Local (Trumbull) - 050153 326
# Maumee City (Lucas) - 044362 327
# Mayfield City (Cuyahoga) - 044370 328
# Maysville Local (Muskingum) - 048850 329
# McComb Local (Hancock) - 047456 330
# McDonald Local (Trumbull) - 050229 331
# Mechanicsburg Exempted Village (Champaign) - 045484 332
# Medina City SD (Medina) - 044388 333
# Meigs Local (Meigs) - 048520 334
# Mentor Exempted Village (Lake) - 045492 335
# Miami East Local (Miami) - 048629 336
# Miami Trace Local (Fayette) - 046920 337
# Miamisburg City (Montgomery) - 044396 338
# Middle Bass Local (Ottawa) - 048959 339
# **** no data ****
# Middletown City (Butler) - 044404 340
# Midview Local (Lorain) - 048173 341
# Milford Exempted Village (Clermont) - 045500 342
# **** no data ****
# Millcreek-West Unity Local (Williams) - 050633 343
# Miller City-New Cleveland Local (Putnam) - 049361 344
# **** no data ****
# Milton-Union Exempted Village (Miami) - 045518 345
# Minerva Local (Stark) - 049890 346
# Minford Local (Scioto) - 049627 347
# Minster Local (Auglaize) - 045948 348
# Mississinawa Valley Local (Darke) - 046672 349
# Mogadore Local (Summit) - 050039 350
# Mohawk Local (Wyandot) - 050740 351
# Monroe Local (Butler) - 139303 352
# Monroeville Local (Huron) - 047712 353
# Montpelier Exempted Village (Williams) - 045526 354
# Morgan Local (Morgan) - 048777 355
# Mount Gilead Exempted Village (Morrow) - 045534 356
# Mount Vernon City (Knox) - 044420 357
# Mt Healthy City (Hamilton) - 044412 358
# Napoleon Area City (Henry) - 044438 359
# National Trail Local (Preble) - 049270 360
# Nelsonville-York City (Athens) - 044446 361
# New Albany-Plain Local (Franklin) - 046995 362
# New Boston Local (Scioto) - 044461 363
# New Bremen Local (Auglaize) - 045955 364
# New Knoxville Local (Auglaize) - 045963 365
# New Lebanon Local School District (Montgomery) - 048710 366
# New Lexington School District (Perry) - 044479 367
# New London Local (Huron) - 047720 368
# New Miami Local (Butler) - 046136 369
# New Philadelphia City (Tuscarawas) - 044487 370
# New Richmond Exempted Village (Clermont) - 045559 371
# New Riegel Local (Seneca) - 049718 372
# Newark City (Licking) - 044453 373
# Newcomerstown Exempted Village (Tuscarawas) - 045542 374
# Newton Falls Exempted Village (Trumbull) - 045567 375
# Newton Local (Miami) - 048637 376
# Niles City (Trumbull) - 044495 377
# Noble Local (Noble) - 048900 378
# Nordonia Hills City (Summit) - 050047 379
# North Baltimore Local (Wood) - 050708 380
# North Bass Local (Ottawa) - 048967 381
# **** no data ****
# North Canton City (Stark) - 044503 382
# North Central Local (Williams) - 050641 383
# North College Hill City (Hamilton) - 044511 384
# North Fork Local (Licking) - 048025 385
# North Olmsted City (Cuyahoga) - 044529 386
# North Ridgeville City (Lorain) - 044537 387
# North Royalton City (Cuyahoga) - 044545 388
# North Union Local School District (Union) - 050336 389
# Northeastern Local (Clark) - 046250 390
# Northeastern Local (Defiance) - 046722 391
# Northern Local (Perry) - 049056 392
# Northmont City (Montgomery) - 048728 393
# Northmor Local (Morrow) - 048819 394
# Northridge Local (Montgomery) - 048736 395
# Northridge Local (Licking) - 048033 396
# Northwest Local (Stark) - 049908 397
# Northwest Local (Hamilton) - 047365 398
# Northwest Local (Scioto) - 049635 399
# Northwestern Local (Clark) - 046268 400
# Northwestern Local (Wayne) - 050575 401
# Northwood Local Schools (Wood) - 050716 402
# Norton City (Summit) - 044552 403
# Norwalk City (Huron) - 044560 404
# Norwayne Local (Wayne) - 050567 405
# Norwood City (Hamilton) - 044578 406
# Oak Hill Union Local (Jackson) - 047761 407
# Oak Hills Local (Hamilton) - 047373 408
# Oakwood City (Montgomery) - 044586 409
# Oberlin City Schools (Lorain) - 044594 410
# Old Fort Local (Seneca) - 049726 411
# Olentangy Local (Delaware) - 046763 412
# Olmsted Falls City (Cuyahoga) - 046573 413
# Ontario Local (Richland) - 049478 414
# Orange City (Cuyahoga) - 046581 415
# Oregon City (Lucas) - 044602 416
# Orrville City (Wayne) - 044610 417
# Osnaburg Local (Stark) - 049916 418
# Otsego Local (Wood) - 050724 419
# Ottawa Hills Local (Lucas) - 048215 420
# Ottawa-Glandorf Local (Putnam) - 049379 421
# Ottoville Local (Putnam) - 049387 422
# Painesville City Local (Lake) - 044628 423
# Paint Valley Local (Ross) - 049510 424
# Pandora-Gilboa Local (Putnam) - 049395 425
# Parkway Local (Mercer) - 048579 426
# Parma City (Cuyahoga) - 044636 427
# Patrick Henry Local (Henry) - 047597 428
# Paulding Exempted Village (Paulding) - 045575 429
# Perkins Local (Erie) - 046813 430
# Perry Local (Allen) - 045781 431
# Perry Local (Stark) - 049924 432
# Perry Local (Lake) - 047902 433
# Perrysburg Exempted Village (Wood) - 045583 434
# Pettisville Local (Fulton) - 047076 435
# Pickerington Local (Fairfield) - 046896 436
# Pike-Delta-York Local (Fulton) - 047084 437
# Piqua City (Miami) - 044644 438
# Plain Local (Stark) - 049932 439
# Pleasant Local (Marion) - 048421 440
# Plymouth-Shiloh Local (Richland) - 049460 441
# Poland Local (Mahoning) - 048348 442
# Port Clinton City (Ottawa) - 044651 443
# Portsmouth City (Scioto) - 044669 444
# Preble Shawnee Local (Preble) - 049288 445
# Princeton City (Hamilton) - 044677 446
# Put-In-Bay Local (Ottawa) - 048975 447
# Pymatuning Valley Local (Ashtabula) - 045880 448
# Ravenna City (Portage) - 044685 449
# Reading Community City (Hamilton) - 044693 450
# Revere Local (Summit) - 050054 451
# Reynoldsburg City (Franklin) - 047001 452
# Richmond Heights Local (Cuyahoga) - 046599 453
# Ridgedale Local (Marion) - 048439 454
# Ridgemont Local (Hardin) - 047506 455
# Ridgewood Local (Coshocton) - 046474 456
# Ripley-Union-Lewis-Huntington Local (Brown) - 046078 457
# Rittman Exempted Village (Wayne) - 045591 458
# River Valley Local (Marion) - 048447 459
# River View Local (Coshocton) - 046482 460
# Riverdale Local (Hancock) - 047514 461
# Riverside Local (Logan) - 048090 462
# Riverside Local (Lake) - 047894 463
# Rock Hill Local (Lawrence) - 047944 464
# Rocky River City (Cuyahoga) - 044701 465
# Rolling Hills Local (Guernsey) - 047308 466
# Rootstown Local (Portage) - 049213 467
# Ross Local (Butler) - 046144 468
# Rossford Exempted Village (Wood) - 045609 469
# Russia Local (Shelby) - 049817 470
# Salem City (Columbiana) - 044735 471
# Sandusky City (Erie) - 044743 472
# Sandy Valley Local (Stark) - 049940 473
# Scioto Valley Local (Pike) - 049130 474
# Sebring Local (Mahoning) - 048355 475
# Seneca East Local (Seneca) - 049684 476
# Shadyside Local (Belmont) - 046003 477
# **** no data ****
# Shaker Heights City (Cuyahoga) - 044750 478
# Shawnee Local (Allen) - 045799 479
# Sheffield-Sheffield Lake City (Lorain) - 044768 480
# Shelby City (Richland) - 044776 481
# Sidney City (Shelby) - 044784 482
# Solon City (Cuyahoga) - 046607 483
# South Central Local (Huron) - 047738 484
# South Euclid-Lyndhurst City (Cuyahoga) - 044792 485
# South Point Local (Lawrence) - 047951 486
# South Range Local (Mahoning) - 048363 487
# South-Western City (Franklin) - 044800 488
# **** no data ****
# Southeast Local (Wayne) - 050583 489
# Southeast Local (Portage) - 049221 490
# Southeastern Local (Ross) - 049528 491
# Southeastern Local (Clark) - 046276 492
# Southern Local (Perry) - 049064 493
# Southern Local (Meigs) - 048538 494
# Southern Local (Columbiana) - 046441 495
# Southington Local (Trumbull) - 050237 496
# Southwest Licking Local (Licking) - 048041 497
# Southwest Local (Hamilton) - 047381 498
# Spencerville Local (Allen) - 045807 499
# Springboro Community City (Warren) - 050427 500
# Springfield City School District (Clark) - 044818 501
# Springfield Local (Summit) - 050062 502
# Springfield Local (Lucas) - 048223 503
# Springfield Local (Mahoning) - 048371 504
# St Bernard-Elmwood Place City (Hamilton) - 044719 505
# St Clairsville-Richland City (Belmont) - 045997 506
# St Henry Consolidated Local (Mercer) - 048587 507
# St Marys City (Auglaize) - 044727 508
# Steubenville City (Jefferson) - 044826 509
# Stow-Munroe Falls City School District (Summit) - 044834 510
# Strasburg-Franklin Local (Tuscarawas) - 050294 511
# Streetsboro City (Portage) - 049239 512
# Strongsville City (Cuyahoga) - 044842 513
# Struthers City (Mahoning) - 044859 514
# Stryker Local (Williams) - 050658 515
# Swanton Local (Fulton) - 047092 516
# Switzerland of Ohio Local (Monroe) - 048652 517
# Sycamore Community City (Hamilton) - 044867 518
# Sylvania Schools (Lucas) - 044875 519
# Symmes Valley Local (Lawrence) - 047969 520
# Talawanda City (Butler) - 046151 521
# Tallmadge City (Summit) - 044883 522
# Teays Valley Local (Pickaway) - 049098 523
# Tecumseh Local (Clark) - 046243 524
# Three Rivers Local (Hamilton) - 047399 525
# Tiffin City (Seneca) - 044891 526
# Tipp City Exempted Village (Miami) - 045617 527
# Toledo City (Lucas) - 044909 528
# Toronto City (Jefferson) - 044917 529
# Tri-County North Local (Preble) - 091397 530
# Tri-Valley Local (Muskingum) - 048876 531
# Tri-Village Local (Darke) - 046680 532
# Triad Local (Champaign) - 046201 533
# Trimble Local (Athens) - 045922 534
# Triway Local (Wayne) - 050591 535
# Trotwood-Madison City (Montgomery) - 048694 536
# Troy City (Miami) - 044925 537
# Tuscarawas Valley Local (Tuscarawas) - 050302 538
# Tuslaw Local (Stark) - 049957 539
# Twin Valley Community Local (Preble) - 049296 540
# **** no data ****
# Twinsburg City (Summit) - 050070 541
# Union Local (Belmont) - 046011 542
# Union-Scioto Local (Ross) - 049536 543
# United Local (Columbiana) - 046458 544
# Upper Arlington City (Franklin) - 044933 545
# Upper Sandusky Exempted Village (Wyandot) - 045625 546
# Upper Scioto Valley Local (Hardin) - 047522 547
# Urbana City (Champaign) - 044941 548
# Valley Local (Scioto) - 049643 549
# Valley View Local (Montgomery) - 048744 550
# Van Buren Local (Hancock) - 047464 551
# Van Wert City (Van Wert) - 044966 552
# Vandalia-Butler City (Montgomery) - 044958 553
# Vanlue Local (Hancock) - 047472 554
# Vermilion Local (Erie) - 046821 555
# Versailles Exempted Village (Darke) - 045633 556
# Vinton County Local (Vinton) - 050393 557
# Wadsworth City (Medina) - 044974 558
# Walnut Township Local (Fairfield) - 046904 559
# Wapakoneta City (Auglaize) - 044982 560
# Warren City (Trumbull) - 044990 561
# Warren Local (Washington) - 050500 562
# Warrensville Heights City (Cuyahoga) - 045005 563
# Washington Court House City (Fayette) - 045013 564
# Washington Local (Lucas) - 048231 565
# Washington-Nile Local (Scioto) - 049650 566
# Waterloo Local (Portage) - 049247 567
# Wauseon Exempted Village (Fulton) - 045641 568
# Waverly City (Pike) - 049148 569
# Wayne Local (Warren) - 050468 570
# Wayne Trace Local (Paulding) - 049031 571
# Waynesfield-Goshen Local (Auglaize) - 045971 572
# Weathersfield Local (Trumbull) - 050252 573
# Wellington Exempted Village (Lorain) - 045658 574
# Wellston City (Jackson) - 045021 575
# Wellsville Local (Columbiana) - 045039 576
# West Branch Local (Mahoning) - 048389 577
# West Carrollton City (Montgomery) - 045054 578
# West Clermont Local (Clermont) - 046359 579
# West Geauga Local (Geauga) - 047225 580
# West Holmes Local (Holmes) - 047696 581
# West Liberty-Salem Local (Champaign) - 046219 582
# West Muskingum Local (Muskingum) - 048884 583
# Western Brown Local (Brown) - 046060 584
# Western Local (Pike) - 049155 585
# Western Reserve Local (Huron) - 047746 586
# Western Reserve Local (Mahoning) - 048397 587
# Westerville City (Franklin) - 045047 588
# Westfall Local (Pickaway) - 049106 589
# Westlake City (Cuyahoga) - 045062 590
# Wheelersburg Local (Scioto) - 049668 591
# Whitehall City (Franklin) - 045070 592
# Wickliffe City (Lake) - 045088 593
# Willard City (Huron) - 045096 594
# Williamsburg Local (Clermont) - 046367 595
# Willoughby-Eastlake City (Lake) - 045104 596
# Wilmington City (Clinton) - 045112 597
# Windham Exempted Village (Portage) - 045666 598
# Winton Woods City (Hamilton) - 044081 599
# Wolf Creek Local (Washington) - 050518 600
# Woodmore Local (Sandusky) - 049577 601
# Woodridge Local (Summit) - 049973 602
# Wooster City (Wayne) - 045120 603
# Worthington City (Franklin) - 045138 604
# Wynford Local (Crawford) - 046524 605
# Wyoming City (Hamilton) - 045146 606
# Xenia Community City (Greene) - 045153 607
# Yellow Springs Exempted Village (Greene) - 045674 608
# Youngstown City (Mahoning) - 045161 609
# Zane Trace Local (Ross) - 049544 610
# Zanesville City (Muskingum) - 045179 611

# %%
df
# Out:
#         IRN  year county_code CS_ADM_sped_total_cat1 CS_ADM_sped_total_cat2
# 0    045187  2021      Hardin                   2.67                   4.94  \
# 1    061903  2021       Adams                   1.42                  13.27
# 2    049494  2021        Ross                   0.00                   0.54
# 3    043489  2021      Summit                  35.57                 459.95
# 4    045906  2021      Athens                   0.00                   7.83
# ..      ...   ...         ...                    ...                    ...
# 606  045153  2021      Greene                   2.45                  44.35
# 607  045674  2021      Greene                   0.00                   0.40
# 608  045161  2021    Mahoning                  55.88                 293.64
# 609  049544  2021        Ross                   0.00                   6.55
# 610  045179  2021   Muskingum                   5.43                  90.10
#
#     CS_ADM_sped_total_cat3 CS_ADM_sped_total_cat4 CS_ADM_sped_total_cat5
# 0                     0.00                   0.00                   0.00  \
# 1                     0.00                   0.00                   0.00
# 2                     0.00                   0.00                   0.00
# 3                    67.52                   1.08                   9.78
# 4                     0.86                   0.00                   0.50
# ..                     ...                    ...                    ...
# 606                   7.77                   0.72                   1.00
# 607                   0.00                   0.00                   0.00
# 608                  56.10                   3.53                   3.54
# 609                   1.00                   0.00                   0.00
# 610                  15.85                   0.00                  12.62
#
#     CS_ADM_sped_total_cat6 CS_CTA_cat1_FTE  ... CS_INT_3 CS_econ_dis_FTE
# 0                     1.00            0.00  ...     0.00           20.38  \
# 1                     0.26            0.66  ...     0.00           83.24
# 2                     0.00            0.46  ...     0.00            7.64
# 3                    69.15          152.98  ...     4.00        2,605.01
# 4                     1.03            1.05  ...     0.00           23.58
# ..                     ...             ...  ...      ...             ...
# 606                  23.02           13.51  ...     0.00          179.43
# 607                   0.68            2.52  ...     0.00            4.90
# 608                  42.57            6.31  ...     6.99        2,131.64
# 609                   0.00            0.24  ...     0.00           27.10
# 610                   4.47            0.84  ...     0.00          334.34
#
#     econ_dis_index  CS_formula_amt CS_econ_disadv_funded  CS_LEP_AID
# 0       0.00000000     $204,034.87               $161.49       $0.00  \
# 1       0.00000000     $655,698.23               $232.54       $0.00
# 2       0.87471730     $117,983.83                $38.07       $0.00
# 3       3.48131143  $17,265,643.61         $2,104,844.34  $48,016.87
# 4       0.86776009     $293,315.08                $25.96       $0.00
# ..             ...             ...                   ...         ...
# 606     2.43057926   $1,676,590.16            $66,488.61       $0.00
# 607     0.00000000     $118,581.81               $413.81       $0.00
# 608     2.76838466  $13,126,701.79         $1,473,245.74  $62,924.87
# 609     0.00000000     $328,955.40               $611.75       $0.00
# 610     3.53854918   $2,154,983.75           $254,115.39       $0.00
#
#     CS_sped_wtd_funds CS_CTA_total_funds CS_TRANS_AID CS_TOTAL_DEDUCT
# 0          $49,634.96            $499.09        $0.00     $254,610.46
# 1          $62,052.73          $6,809.92        $0.00     $724,964.97
# 2           $2,162.70          $2,821.67        $0.00     $123,039.92
# 3       $4,504,647.68      $1,521,690.10  $127,591.56  $26,546,276.53
# 4          $74,735.18          $7,250.75        $0.00     $375,338.03
# ..                ...                ...          ...             ...
# 606       $873,050.05        $101,302.78        $0.00   $2,733,753.46
# 607        $19,035.16         $17,099.80        $0.00     $155,130.58
# 608     $3,002,257.46        $391,055.13   $41,144.14  $19,653,172.01
# 609        $35,854.75          $2,152.58        $0.00     $367,848.91
# 610       $855,986.93          $8,123.38        $0.00   $3,361,230.59
#
# [611 rows x 26 columns]

# %%
df= pd.read_csv("Community 2014-2021/Community_2015.csv")

# %%
missed_ones= list(df[df.CS_ADM_sped_total_cat1.isna()].IRN)

# %%
missed_ones
# Out:
# [46797, 47209, 48959, 44412, 48967, 48975]

# %%
len(missed_ones)
# Out:
# 6

# %%
df2 = pd.DataFrame(columns = colnames)

# %%
#set chromodriver.exe path
driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")
driver.implicitly_wait(0.5)

#first one is total 
for i in range(0, len(missed_ones)): 
    print(str(missed_ones[i]) + " " + str(i))
    time.sleep(1)
    url = "https://reports.education.ohio.gov/finance/legacy-report" 
    driver.get(url)
    driver.implicitly_wait(10)
    time.sleep(3)

    ## scrape 2000
    YEAR = 2015
    FINAL = "Final #5"
    #first step, fill in info, press go 

    # fill in LEA type 
    text_box_path = '/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input'
    text_box = driver.find_element(By.XPATH, text_box_path)
    text_box.send_keys("Traditional School District")

    text_box_selection_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div"
    time.sleep(.25)
    drop_box_1 = driver.find_element(By.XPATH, text_box_selection_path)
    time.sleep(.25)
    drop_box_1.click()

    #fill in year 

    year_text_box_path ="/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[2]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    year_text_box = driver.find_element(By.XPATH, year_text_box_path)
    year_text_box.send_keys(YEAR)

    year_drop_select ="/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[2]/ul/li[2]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"
    time.sleep(.25)
    drop_box_2 = driver.find_element(By.XPATH, year_drop_select)
    time.sleep(.25)
    drop_box_2.click()

    time.sleep(.25)
    go_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[3]/button"
    time.sleep(.25)
    go_button = driver.find_element(By.XPATH, go_path)
    time.sleep(.25)

    go_button_bool = None
    while not go_button_bool:
        try:
            go_button.click()
            go_button_bool=1
        except ElementClickInterceptedException:
            print('********** wait element click error **********')
            time.sleep(2)


    time.sleep(.25)
    #next step 

    payment_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[3]/div/ul/li/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    payment_path_box = driver.find_element(By.XPATH, payment_path)
    time.sleep(.25)

    payment_path_box.send_keys(FINAL)
    payment_path_selection_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[3]/div/ul/li/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"

    time.sleep(.25)
    drop_box_3 = driver.find_element(By.XPATH, payment_path_selection_path)
    drop_box_3.click()

    #next step is to find all LEA values 

    lea_box_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    lea_arrow_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div"

    #click on arrow to show options 
    driver.find_element(By.XPATH, lea_arrow_path).click()

    time.sleep(.25)
    drop_down_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div"
    drop_down= driver.find_element(By.XPATH, drop_down_path)

    drop_down_school_district_path= "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    drop_down_school_district= driver.find_element(By.XPATH, drop_down_school_district_path)
    just_name =list_school_names[i].split("(")[0].strip()
    #try doing by key. 
    IRA_i = missed_ones[i]
    drop_down_school_district.send_keys(IRA_i) #list_school_names[i])

    school_district_select_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"

    drop_box_4 = driver.find_element(By.XPATH, school_district_select_path)

    drop_button_bool = None
    while not drop_button_bool:
        try:
            drop_box_4 = driver.find_element(By.XPATH, school_district_select_path)
            drop_button_bool=1
        except NoSuchElementException:
            time.sleep(2)


    #except NoSuchElementException: 
    #    drop_down_school_district_path= "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    #    drop_down_school_district= driver.find_element(By.XPATH, drop_down_school_district_path)
    #    just_name =list_school_names[i].split("(")[0].strip()
    #    drop_down_school_district.send_keys(just_name)
    #    drop_box_4 = driver.find_element(By.XPATH, school_district_select_path)

    drop_box_4.click()

    time.sleep(.25)
    #click process button! 
    process_button_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[3]/ul/li[2]/button"
    driver.find_element(By.XPATH, process_button_path).click()
    time.sleep(2)

    ## new code here     

    
    page_bool = None
    while not page_bool:
        try:
            testing_web_text= driver.page_source
            page_bool=1
        except IndexError:
            print('********** wait index error **********')
            url = "https://reports.education.ohio.gov/finance/legacy-report" 
            time.sleep(2)
            
       
    IRA_i = missed_ones[i]
    county_i= "fill in"#list_school_names[i].split("(")[1].split()[0].split(")")[0]
    

    if testing_web_text.find("District Breakdown") == -1: #DISTRICT BREAKDOWN (2014)
        list_i = [IRA_i, YEAR, county_i] + ['N/A'] *(len(colnames)-3)
        print("**** no data ****")
  
    else: 
        testing_web_text= driver.page_source
        main= testing_web_text.split("District Breakdown")[-1]
        main= main.split("IRN: All")[1]
        total_student_fte= main.split("Total Student FTE:")[1].split()[0]

        CS_ADM_sped_total_cat1= main.split("Category 1 Special Education FTE:")[1].split()[0]
        CS_ADM_sped_total_cat2= main.split("Category 2 Special Education FTE:")[1].split()[0]
        CS_ADM_sped_total_cat3= main.split("Category 3 Special Education FTE:")[1].split()[0]
        CS_ADM_sped_total_cat4= main.split("Category 4 Special Education FTE:")[1].split()[0]
        CS_ADM_sped_total_cat5= main.split("Category 5 Special Education FTE:")[1].split()[0]
        CS_ADM_sped_total_cat6= main.split("Category 6 Special Education FTE:")[1].split()[0]

        CS_CTA_cat1_FTE= main.split("Category 1 Career Tech FTE:")[1].split()[0]
        CS_CTA_cat2_FTE= main.split("Category 2 Career Tech FTE:")[1].split()[0]
        CS_CTA_cat3_FTE= main.split("Category 3 Career Tech FTE:")[1].split()[0]
        CS_CTA_cat4_FTE= main.split("Category 4 Career Tech FTE:")[1].split()[0]
        CS_CTA_cat5_FTE= main.split("Category 5 Career Tech FTE:")[1].split()[0]

        CS_INT_1= main.split("Category 1 LEP FTE:")[1].split()[0]
        CS_INT_2= main.split("Category 2 LEP FTE:")[1].split()[0]
        CS_INT_3= main.split("Category 3 LEP FTE:")[1].split()[0]

        CS_econ_dis_FTE= main.split("Economic Disadvantaged FTE:")[1].split()[0]
        econ_dis_index= main.split("District's Economically Disadvantaged Index:")[1].split()[0]

        CS_formula_amt= main.split("Opportunity Grant")[1].split("\n")[0].split()[-1]
        CS_econ_disadv_funded= main.split("Economic Disadvantaged Funding")[1].split("\n")[0].split()[-1]
        CS_LEP_AID = main.split("Limited English Proficiency Funding")[1].split("\n")[0].split()[-1]

        CS_sped_wtd_funds =main.split("Special Education Additional Funding")[1].split("\n")[0].split()[-1]
        CS_CTA_total_funds= main.split("Career Tech Education Funding")[1].split("\n")[0].split()[-1]
        CS_TRANS_AID= main.split("Transportation Funding:")[1].split()[0]
        CS_TOTAL_DEDUCT= main.split("Total Deduction Amounts")[1].split("\n")[0].split()[-1]

        list_i = [IRA_i, YEAR, county_i, 
                  CS_ADM_sped_total_cat1, CS_ADM_sped_total_cat2, CS_ADM_sped_total_cat3, CS_ADM_sped_total_cat4, CS_ADM_sped_total_cat5, CS_ADM_sped_total_cat6,
                  CS_CTA_cat1_FTE, CS_CTA_cat2_FTE, CS_CTA_cat3_FTE, CS_CTA_cat4_FTE, CS_CTA_cat5_FTE, 
                  CS_INT_1,  CS_INT_2, CS_INT_3,
                  CS_econ_dis_FTE, econ_dis_index, 
                  CS_formula_amt, CS_econ_disadv_funded, CS_LEP_AID, 
                  CS_sped_wtd_funds, CS_CTA_total_funds, CS_TRANS_AID, CS_TOTAL_DEDUCT
                   ]
    df2.loc[len(df2)] = list_i
    #list_list= list_list.append(list_i)

df2.to_csv("Community_" + str(YEAR) + "_2.csv")
# Out:
# /var/folders/09/l3m63nj90fg1l2jshjp_hd5w0000gn/T/ipykernel_22777/365558810.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")
# 46797 0
# **** no data ****
# 47209 1
# **** no data ****
# 48959 2
# **** no data ****
# 44412 3
# 48967 4
# **** no data ****
# 48975 5
# **** no data ****

# %%
df2.to_csv("Community_" + str(2015) + "_2.csv")
