# %%
import time 
import pandas as pd 
from selenium import webdriver 
from selenium.webdriver import Chrome 
from selenium.webdriver.chrome.service import Service 
from selenium.webdriver.common.by import By 
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import ElementClickInterceptedException, NoSuchElementException
from selenium import webdriver

# %%
from selenium import webdriver
#set chromodriver.exe path
driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")
driver.implicitly_wait(0.5)
# Out:
# /var/folders/09/l3m63nj90fg1l2jshjp_hd5w0000gn/T/ipykernel_44998/391032499.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")

# %%
years_list= ['2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013'] 
final_val_list=["Final #5", "Final #3", "Final #2", "Final #5", 'Final #6', 'Final #3', 'Final #5', 'Final #2', 'Final #3', 'Final #4']

# %%
def get_school_list(year, final_val): 
    time.sleep(1)
    driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")
    driver.implicitly_wait(0.5)
    url = "https://reports.education.ohio.gov/finance/legacy-report" 
    driver.get(url)
    driver.implicitly_wait(10)
    time.sleep(3)

    ## scrape 2000
    YEAR = year
    FINAL = final_val
    #first step, fill in info, press go 

    # fill in LEA type 
    text_box_path = '/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input'
    text_box = driver.find_element(By.XPATH, text_box_path)
    text_box.send_keys("Traditional School District")

    text_box_selection_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div"
    time.sleep(.25)
    drop_box_1 = driver.find_element(By.XPATH, text_box_selection_path)
    time.sleep(.25)
    drop_box_1.click()

    #fill in year 

    year_text_box_path ="/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[2]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    year_text_box = driver.find_element(By.XPATH, year_text_box_path)
    year_text_box.send_keys(YEAR)

    year_drop_select ="/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[2]/ul/li[2]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"
    time.sleep(.25)
    drop_box_2 = driver.find_element(By.XPATH, year_drop_select)
    time.sleep(.25)
    drop_box_2.click()

    time.sleep(.25)
    go_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[3]/button"
    time.sleep(.25)
    go_button = driver.find_element(By.XPATH, go_path)
    time.sleep(.25)

    go_button_bool = None
    while not go_button_bool:
        try:
            go_button.click()
            go_button_bool=1
        except ElementClickInterceptedException:
            time.sleep(2)

    time.sleep(.25)
    #next step 

    payment_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[3]/div/ul/li/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    payment_path_box = driver.find_element(By.XPATH, payment_path)
    time.sleep(.25)

    payment_path_box.send_keys(FINAL)
    payment_path_selection_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[3]/div/ul/li/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"

    time.sleep(.25)
    drop_box_3 = driver.find_element(By.XPATH, payment_path_selection_path)
    drop_box_3.click()

    #next step is to find all LEA values 

    lea_box_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    lea_arrow_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div"

    #click on arrow to show options 
    driver.find_element(By.XPATH, lea_arrow_path).click()

    time.sleep(.25)
    drop_down_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div"
    drop_down= driver.find_element(By.XPATH, drop_down_path)

    ddt= drop_down.text
    list_school_names_i = ddt.splitlines()
    
    return(list_school_names_i)

# %%
#set chromodriver.exe path
driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")
driver.implicitly_wait(0.5)
# Out:
# /var/folders/09/l3m63nj90fg1l2jshjp_hd5w0000gn/T/ipykernel_44998/553504982.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")

# %%
i=3 #2000
year = years_list[i]
print(year)
final_val = final_val_list[i]
list_school_names= get_school_list(year, final_val) 

colnames= ["IRN", "year", "county_code", 'CS_ADM_sped_cat1_K', 'CS_ADM_sped_cat2_K', 'CS_ADM_sped_cat3_K', 'CS_ADM_sped_cat4_K', 'CS_ADM_sped_cat5_K', 'CS_ADM_sped_cat6_K', 'CS_ADM_other_K', 'CS_ADM_total_K',
             'CS_ADM_sped_cat1_1to12', 'CS_ADM_sped_cat2_1to12', 'CS_ADM_sped_cat3_1to12', 'CS_ADM_sped_cat4_1to12', 'CS_ADM_sped_cat5_1to12', 'CS_ADM_sped_cat6_1to12', 'CS_ADM_other_1to12', 'CS_ADM_total_1to12',
             'CS_sped_wtd_funds', 'CS_formula_amt', # cut 5 
             'CS_TOTAL_DEDUCT', 'CS_JVS_FTE', 'CS_CTA_cat1_FTE', 'CS_CTA_cat2_FTE', 'CS_CTA_total_funds', 'CS_parity_aid',
             'CS_LEP_FTE', 'CS_INT_1', 'CS_INT_2', 'CS_INT_3', 'CS_LEP_AID', 'CS_PBA_PD_AID', #added row
             'CS_PBA_allday_K', 'CS_PBA_PD_AID', 'CS_PBA_CSR', 'CS_PBA_CO', 'CS_PBA_GUAR' #added row 
          
          ]
# Out:
# 2007
# /var/folders/09/l3m63nj90fg1l2jshjp_hd5w0000gn/T/ipykernel_44998/1708469783.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")

# %%
df = pd.DataFrame(columns = colnames)

# %%
list_school_names
# Out:
# ['State Totals (All Counties) - 999999',
#  'Ada Exempted Village (Hardin) - 045187',
#  'Adams County Ohio Valley Local (Adams) - 061903',
#  'Adena Local (Ross) - 049494',
#  'Akron City (Summit) - 043489',
#  'Alexander Local (Athens) - 045906',
#  'Allen East Local (Allen) - 045757',
#  'Alliance City (Stark) - 043497',
#  'Amanda-Clearcreek Local (Fairfield) - 046847',
#  'Amherst Exempted Village (Lorain) - 045195',
#  'Anna Local (Shelby) - 049759',
#  'Ansonia Local (Darke) - 046623',
#  'Anthony Wayne Local (Lucas) - 048207',
#  'Antwerp Local (Paulding) - 048991',
#  'Arcadia Local (Hancock) - 047415',
#  'Arcanum-Butler Local (Darke) - 046631',
#  'Archbold-Area Local (Fulton) - 047043',
#  'Arlington Local (Hancock) - 047423',
#  'Ashland City (Ashland) - 043505',
#  'Ashtabula Area City (Ashtabula) - 043513',
#  'Athens City (Athens) - 043521',
#  'Aurora City (Portage) - 049171',
#  'Austintown Local Schools (Mahoning) - 048298',
#  'Avon Lake City (Lorain) - 048124',
# ...

# %%
# Out:
# /var/folders/09/l3m63nj90fg1l2jshjp_hd5w0000gn/T/ipykernel_9643/553504982.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")

# %%
#set chromodriver.exe path
driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")
driver.implicitly_wait(0.5)

#first one is total 
for i in range(1, len(list_school_names)): 
    print(list_school_names[i] + " " + str(i))
    time.sleep(1)
    url = "https://reports.education.ohio.gov/finance/legacy-report" 
    driver.get(url)
    driver.implicitly_wait(10)
    time.sleep(3)

    ## scrape 2000
    YEAR = year
    FINAL = final_val
    #first step, fill in info, press go 

    # fill in LEA type 
    text_box_path = '/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input'
    text_box = driver.find_element(By.XPATH, text_box_path)
    text_box.send_keys("Traditional School District")

    text_box_selection_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div"
    time.sleep(.25)
    drop_box_1 = driver.find_element(By.XPATH, text_box_selection_path)
    time.sleep(.25)
    drop_box_1.click()

    #fill in year 

    year_text_box_path ="/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[2]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    year_text_box = driver.find_element(By.XPATH, year_text_box_path)
    year_text_box.send_keys(YEAR)

    year_drop_select ="/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[2]/ul/li[2]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"
    time.sleep(.25)
    drop_box_2 = driver.find_element(By.XPATH, year_drop_select)
    time.sleep(.25)
    drop_box_2.click()

    time.sleep(.25)
    go_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[3]/button"
    time.sleep(.25)
    go_button = driver.find_element(By.XPATH, go_path)
    time.sleep(.25)

    go_button_bool = None
    while not go_button_bool:
        try:
            go_button.click()
            go_button_bool=1
        except ElementClickInterceptedException:
            print('********** wait element click error **********')
            time.sleep(2)


    time.sleep(.25)
    #next step 

    payment_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[3]/div/ul/li/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    payment_path_box = driver.find_element(By.XPATH, payment_path)
    time.sleep(.25)

    payment_path_box.send_keys(FINAL)
    payment_path_selection_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[3]/div/ul/li/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"

    time.sleep(.25)
    drop_box_3 = driver.find_element(By.XPATH, payment_path_selection_path)
    drop_box_3.click()

    #next step is to find all LEA values 

    lea_box_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    lea_arrow_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div"

    #click on arrow to show options 
    driver.find_element(By.XPATH, lea_arrow_path).click()

    time.sleep(.25)
    drop_down_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div"
    drop_down= driver.find_element(By.XPATH, drop_down_path)

    drop_down_school_district_path= "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    drop_down_school_district= driver.find_element(By.XPATH, drop_down_school_district_path)
    just_name =list_school_names[i].split("(")[0].strip()
    #try doing by key. 
    IRA_i = list_school_names[i].split()[-1]
    drop_down_school_district.send_keys(IRA_i) #list_school_names[i])

    school_district_select_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"

    drop_box_4 = driver.find_element(By.XPATH, school_district_select_path)

    drop_button_bool = None
    while not drop_button_bool:
        try:
            drop_box_4 = driver.find_element(By.XPATH, school_district_select_path)
            drop_button_bool=1
        except NoSuchElementException:
            time.sleep(2)


    #except NoSuchElementException: 
    #    drop_down_school_district_path= "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    #    drop_down_school_district= driver.find_element(By.XPATH, drop_down_school_district_path)
    #    just_name =list_school_names[i].split("(")[0].strip()
    #    drop_down_school_district.send_keys(just_name)
    #    drop_box_4 = driver.find_element(By.XPATH, school_district_select_path)

    drop_box_4.click()

    time.sleep(.25)
    #click process button! 
    process_button_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[3]/ul/li[2]/button"
    driver.find_element(By.XPATH, process_button_path).click()
    time.sleep(2)

    ## new code here     

    
    page_bool = None
    while not page_bool:
        try:
            testing_web_text= driver.page_source
            page_bool=1
        except IndexError:
            print('********** wait index error **********')
            url = "https://reports.education.ohio.gov/finance/legacy-report" 
            time.sleep(2)
            
       
    IRA_i = list_school_names[i].split()[-1]
    county_i= list_school_names[i].split("(")[1].split()[0].split(")")[0]
    

    if testing_web_text.find("Community School Deduct") == -1: 
        list_i = [IRA_i, YEAR, county_i] + ['N/A'] *(len(colnames)-3)
        print("**** no data ****")
  
    else: 
        main_totals= testing_web_text.split("Community School Deduct")[1].split("TOTALS:")[1].split("<hr>")[0].strip().splitlines()
        
        CS_ADM_sped_cat1_K= main_totals[1].strip().split()[0]
        CS_ADM_sped_cat2_K= main_totals[1].strip().split()[1]
        CS_ADM_sped_cat3_K= main_totals[1].strip().split()[2]
        CS_ADM_sped_cat4_K= main_totals[1].strip().split()[3]
        CS_ADM_sped_cat5_K= main_totals[1].strip().split()[4]
        CS_ADM_sped_cat6_K= main_totals[1].strip().split()[5]
        CS_ADM_other_K= main_totals[1].strip().split()[6]
        CS_ADM_total_K= main_totals[1].strip().split()[7]

        CS_ADM_sped_cat1_1to12 = main_totals[3].strip().split()[0]
        CS_ADM_sped_cat2_1to12 = main_totals[3].strip().split()[1]
        CS_ADM_sped_cat3_1to12 = main_totals[3].strip().split()[2]
        CS_ADM_sped_cat4_1to12 = main_totals[3].strip().split()[3]
        CS_ADM_sped_cat5_1to12 = main_totals[3].strip().split()[4]
        CS_ADM_sped_cat6_1to12 = main_totals[3].strip().split()[5]
        CS_ADM_other_1to12 =  main_totals[3].strip().split()[6]
        CS_ADM_total_1to12 = main_totals[3].strip().split()[7]
        CS_JVS_FTE= main_totals[3].strip().split()[8]
        CS_LEP_FTE= main_totals[3].strip().split()[9]
        
        
        CS_formula_amt= main_totals[5].strip().split()[0]
        CS_INT_1= main_totals[5].strip().split()[1]
        CS_INT_2=main_totals[5].strip().split()[2]
        CS_INT_3= main_totals[5].strip().split()[3]
        CS_LEP_AID= main_totals[5].strip().split()[4]
        CS_PBA_PD_AID= main_totals[5].strip().split()[5]

        
        CS_PBA_allday_K= main_totals[8].strip().split()[0]
        CS_PBA_PD_AID= main_totals[8].strip().split()[2]
        #change name below for 2008!!! 
        CS_PBA_CSR= main_totals[8].strip().split()[3]
        CS_PBA_CO= main_totals[8].strip().split()[4]
        CS_PBA_GUAR= main_totals[8].strip().split()[5]
        CS_sped_wtd_funds = main_totals[8].strip().split()[6]

        CS_CTA_cat1_FTE= main_totals[10].strip().split()[0]
        CS_CTA_cat2_FTE= main_totals[10].strip().split()[1]
        CS_CTA_total_funds= main_totals[10].strip().split()[2]
        CS_parity_aid= main_totals[10].strip().split()[3]
        CS_TOTAL_DEDUCT=  main_totals[10].strip().split()[4]

        #testing_web_text= driver.page_source
        #GT_units= testing_web_text.split("Gifted Aid")[1].split("\n")[0].split()[1]

        
        colnames= ["IRN", "year", "county_code", 'CS_ADM_sped_cat1_K', 'CS_ADM_sped_cat2_K', 'CS_ADM_sped_cat3_K', 'CS_ADM_sped_cat4_K', 'CS_ADM_sped_cat5_K', 'CS_ADM_sped_cat6_K', 'CS_ADM_other_K', 'CS_ADM_total_K',
             'CS_ADM_sped_cat1_1to12', 'CS_ADM_sped_cat2_1to12', 'CS_ADM_sped_cat3_1to12', 'CS_ADM_sped_cat4_1to12', 'CS_ADM_sped_cat5_1to12', 'CS_ADM_sped_cat6_1to12', 'CS_ADM_other_1to12', 'CS_ADM_total_1to12',
             'CS_sped_wtd_funds', 'CS_formula_amt', 
             'CS_TOTAL_DEDUCT', 'CS_JVS_FTE', 'CS_CTA_cat1_FTE', 'CS_CTA_cat2_FTE', 'CS_CTA_total_funds', 'CS_parity_aid',
             'CS_LEP_FTE', 'CS_INT_1', 'CS_INT_2', 'CS_INT_3', 'CS_LEP_AID', 'CS_PBA_PD_AID', #added row
             'CS_PBA_allday_K', 'CS_PBA_PD_AID', 'CS_PBA_CSR', 'CS_PBA_CO', 'CS_PBA_GUAR' #added row 
          
          ] 

        
        list_i = [IRA_i, YEAR, county_i, CS_ADM_sped_cat1_K, CS_ADM_sped_cat2_K, CS_ADM_sped_cat3_K, CS_ADM_sped_cat4_K, CS_ADM_sped_cat5_K, CS_ADM_sped_cat6_K, CS_ADM_other_K, CS_ADM_total_K,
             CS_ADM_sped_cat1_1to12, CS_ADM_sped_cat2_1to12, CS_ADM_sped_cat3_1to12, CS_ADM_sped_cat4_1to12, CS_ADM_sped_cat5_1to12, CS_ADM_sped_cat6_1to12, CS_ADM_other_1to12, CS_ADM_total_1to12,
             CS_sped_wtd_funds, CS_formula_amt,
             CS_TOTAL_DEDUCT, CS_JVS_FTE, CS_CTA_cat1_FTE, CS_CTA_cat2_FTE, CS_CTA_total_funds, CS_parity_aid,
                 CS_LEP_FTE, CS_INT_1, CS_INT_2, CS_INT_3, CS_LEP_AID, CS_PBA_PD_AID, 
                  CS_PBA_allday_K, CS_PBA_PD_AID, CS_PBA_CSR, CS_PBA_CO, CS_PBA_GUAR
                 ]

    df.loc[len(df)] = list_i
    #list_list= list_list.append(list_i)

df.to_csv("Community_" + str(year) + ".csv")
# Out:
# /var/folders/09/l3m63nj90fg1l2jshjp_hd5w0000gn/T/ipykernel_44998/1626994328.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")
# Ada Exempted Village (Hardin) - 045187 1
# Adams County Ohio Valley Local (Adams) - 061903 2
# Adena Local (Ross) - 049494 3
# Akron City (Summit) - 043489 4
# Alexander Local (Athens) - 045906 5
# Allen East Local (Allen) - 045757 6
# Alliance City (Stark) - 043497 7
# Amanda-Clearcreek Local (Fairfield) - 046847 8
# Amherst Exempted Village (Lorain) - 045195 9
# Anna Local (Shelby) - 049759 10
# Ansonia Local (Darke) - 046623 11
# Anthony Wayne Local (Lucas) - 048207 12
# **** no data ****
# Antwerp Local (Paulding) - 048991 13
# Arcadia Local (Hancock) - 047415 14
# Arcanum-Butler Local (Darke) - 046631 15
# Archbold-Area Local (Fulton) - 047043 16
# Arlington Local (Hancock) - 047423 17
# Ashland City (Ashland) - 043505 18
# ...

# %%
df
# Out:
#         IRN  year county_code CS_ADM_sped_cat1_K CS_ADM_sped_cat2_K
# 0    045187  2007      Hardin               0.00               0.00  \
# 1    061903  2007       Adams               0.00               0.00
# 2    049494  2007        Ross               0.00               0.00
# 3    043489  2007      Summit               5.98               2.90
# 4    045906  2007      Athens               0.00               0.00
# ..      ...   ...         ...                ...                ...
# 609  045153  2007      Greene               0.00               0.00
# 610  045674  2007      Greene                N/A                N/A
# 611  045161  2007    Mahoning              18.48               2.00
# 612  049544  2007        Ross               0.00               0.00
# 613  045179  2007   Muskingum               0.00               0.00
#
#     CS_ADM_sped_cat3_K CS_ADM_sped_cat4_K CS_ADM_sped_cat5_K
# 0                 0.00               0.00               0.00  \
# ...

# %%
df= pd.read_csv("Community_2007.csv")

# %%
missed_ones= list(df[df.CS_ADM_sped_cat1_K.isna()].IRN)

# %%
len(missed_ones)
# Out:
# 19

# %%
df2 = pd.DataFrame(columns = colnames)

# %%
#years_list= ['2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013'] 
#final_val_list=["Final #5", "Final #3", "Final #2", "Final #5", 'Final #6', 'Final #3', 'Final #5', 'Final #2', 'Final #3', 'Final #4']


#set chromodriver.exe path
driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")
driver.implicitly_wait(0.5)

#first one is total 
for i in range(0, len(missed_ones)): 
    print(str(missed_ones[i]) + " " + str(i))
    time.sleep(1)
    url = "https://reports.education.ohio.gov/finance/legacy-report" 
    driver.get(url)
    driver.implicitly_wait(10)
    time.sleep(3)

    ## scrape 2000
    YEAR = 2007
    FINAL = "Final #5"
    #first step, fill in info, press go 

    # fill in LEA type 
    text_box_path = '/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input'
    text_box = driver.find_element(By.XPATH, text_box_path)
    text_box.send_keys("Traditional School District")

    text_box_selection_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div"
    time.sleep(.25)
    drop_box_1 = driver.find_element(By.XPATH, text_box_selection_path)
    time.sleep(.25)
    drop_box_1.click()

    #fill in year 

    year_text_box_path ="/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[2]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    year_text_box = driver.find_element(By.XPATH, year_text_box_path)
    year_text_box.send_keys(YEAR)

    year_drop_select ="/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[2]/ul/li[2]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"
    time.sleep(.25)
    drop_box_2 = driver.find_element(By.XPATH, year_drop_select)
    time.sleep(.25)
    drop_box_2.click()

    time.sleep(.25)
    go_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[3]/button"
    time.sleep(.25)
    go_button = driver.find_element(By.XPATH, go_path)
    time.sleep(.25)

    go_button_bool = None
    while not go_button_bool:
        try:
            go_button.click()
            go_button_bool=1
        except ElementClickInterceptedException:
            print('********** wait element click error **********')
            time.sleep(2)


    time.sleep(.25)
    #next step 

    payment_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[3]/div/ul/li/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    payment_path_box = driver.find_element(By.XPATH, payment_path)
    time.sleep(.25)

    payment_path_box.send_keys(FINAL)
    payment_path_selection_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[3]/div/ul/li/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"

    time.sleep(.25)
    drop_box_3 = driver.find_element(By.XPATH, payment_path_selection_path)
    drop_box_3.click()

    #next step is to find all LEA values 

    lea_box_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    lea_arrow_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div"

    #click on arrow to show options 
    driver.find_element(By.XPATH, lea_arrow_path).click()

    time.sleep(.25)
    drop_down_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div"
    drop_down= driver.find_element(By.XPATH, drop_down_path)

    drop_down_school_district_path= "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    drop_down_school_district= driver.find_element(By.XPATH, drop_down_school_district_path)
    just_name =list_school_names[i].split("(")[0].strip()
    #try doing by key. 
    IRA_i = missed_ones[i]
    drop_down_school_district.send_keys(IRA_i) #list_school_names[i])

    school_district_select_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"

    drop_box_4 = driver.find_element(By.XPATH, school_district_select_path)

    drop_button_bool = None
    while not drop_button_bool:
        try:
            drop_box_4 = driver.find_element(By.XPATH, school_district_select_path)
            drop_button_bool=1
        except NoSuchElementException:
            time.sleep(2)


    #except NoSuchElementException: 
    #    drop_down_school_district_path= "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    #    drop_down_school_district= driver.find_element(By.XPATH, drop_down_school_district_path)
    #    just_name =list_school_names[i].split("(")[0].strip()
    #    drop_down_school_district.send_keys(just_name)
    #    drop_box_4 = driver.find_element(By.XPATH, school_district_select_path)

    drop_box_4.click()

    time.sleep(.25)
    #click process button! 
    process_button_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[3]/ul/li[2]/button"
    driver.find_element(By.XPATH, process_button_path).click()
    time.sleep(2)

    ## new code here     

    
    page_bool = None
    while not page_bool:
        try:
            testing_web_text= driver.page_source
            page_bool=1
        except IndexError:
            print('********** wait index error **********')
            url = "https://reports.education.ohio.gov/finance/legacy-report" 
            time.sleep(2)
            
       
    IRA_i = missed_ones[i]
    county_i= "fill in"
    

    if testing_web_text.find("Community School Deduct") == -1: 
        list_i = [IRA_i, YEAR, county_i] + ['N/A'] *(len(colnames)-3)
        print("**** no data ****")
  
    else: 
        main_totals= testing_web_text.split("Community School Deduct")[1].split("TOTALS:")[1].split("<hr>")[0].strip().splitlines()
        
        CS_ADM_sped_cat1_K= main_totals[1].strip().split()[0]
        CS_ADM_sped_cat2_K= main_totals[1].strip().split()[1]
        CS_ADM_sped_cat3_K= main_totals[1].strip().split()[2]
        CS_ADM_sped_cat4_K= main_totals[1].strip().split()[3]
        CS_ADM_sped_cat5_K= main_totals[1].strip().split()[4]
        CS_ADM_sped_cat6_K= main_totals[1].strip().split()[5]
        CS_ADM_other_K= main_totals[1].strip().split()[6]
        CS_ADM_total_K= main_totals[1].strip().split()[7]

        CS_ADM_sped_cat1_1to12 = main_totals[3].strip().split()[0]
        CS_ADM_sped_cat2_1to12 = main_totals[3].strip().split()[1]
        CS_ADM_sped_cat3_1to12 = main_totals[3].strip().split()[2]
        CS_ADM_sped_cat4_1to12 = main_totals[3].strip().split()[3]
        CS_ADM_sped_cat5_1to12 = main_totals[3].strip().split()[4]
        CS_ADM_sped_cat6_1to12 = main_totals[3].strip().split()[5]
        CS_ADM_other_1to12 =  main_totals[3].strip().split()[6]
        CS_ADM_total_1to12 = main_totals[3].strip().split()[7]
        CS_JVS_FTE= main_totals[3].strip().split()[8]
        CS_LEP_FTE= main_totals[3].strip().split()[9]
        
        
        CS_formula_amt= main_totals[5].strip().split()[0]
        CS_INT_1= main_totals[5].strip().split()[1]
        CS_INT_2=main_totals[5].strip().split()[2]
        CS_INT_3= main_totals[5].strip().split()[3]
        CS_LEP_AID= main_totals[5].strip().split()[4]
        CS_PBA_PD_AID= main_totals[5].strip().split()[5]

        
        CS_PBA_allday_K= main_totals[8].strip().split()[0]
        CS_PBA_PD_AID= main_totals[8].strip().split()[2]
        #change name below for 2008!!! 
        CS_PBA_CSR= main_totals[8].strip().split()[3]
        CS_PBA_CO= main_totals[8].strip().split()[4]
        CS_PBA_GUAR= main_totals[8].strip().split()[5]
        CS_sped_wtd_funds = main_totals[8].strip().split()[6]

        CS_CTA_cat1_FTE= main_totals[10].strip().split()[0]
        CS_CTA_cat2_FTE= main_totals[10].strip().split()[1]
        CS_CTA_total_funds= main_totals[10].strip().split()[2]
        CS_parity_aid= main_totals[10].strip().split()[3]
        CS_TOTAL_DEDUCT=  main_totals[10].strip().split()[4]

        #testing_web_text= driver.page_source
        #GT_units= testing_web_text.split("Gifted Aid")[1].split("\n")[0].split()[1]

        
        colnames= ["IRN", "year", "county_code", 'CS_ADM_sped_cat1_K', 'CS_ADM_sped_cat2_K', 'CS_ADM_sped_cat3_K', 'CS_ADM_sped_cat4_K', 'CS_ADM_sped_cat5_K', 'CS_ADM_sped_cat6_K', 'CS_ADM_other_K', 'CS_ADM_total_K',
             'CS_ADM_sped_cat1_1to12', 'CS_ADM_sped_cat2_1to12', 'CS_ADM_sped_cat3_1to12', 'CS_ADM_sped_cat4_1to12', 'CS_ADM_sped_cat5_1to12', 'CS_ADM_sped_cat6_1to12', 'CS_ADM_other_1to12', 'CS_ADM_total_1to12',
             'CS_sped_wtd_funds', 'CS_formula_amt', 
             'CS_TOTAL_DEDUCT', 'CS_JVS_FTE', 'CS_CTA_cat1_FTE', 'CS_CTA_cat2_FTE', 'CS_CTA_total_funds', 'CS_parity_aid',
             'CS_LEP_FTE', 'CS_INT_1', 'CS_INT_2', 'CS_INT_3', 'CS_LEP_AID', 'CS_PBA_PD_AID', #added row
             'CS_PBA_allday_K', 'CS_PBA_PD_AID', 'CS_PBA_CSR', 'CS_PBA_CO', 'CS_PBA_GUAR' #added row 
          
          ] 

        
        list_i = [IRA_i, YEAR, county_i, CS_ADM_sped_cat1_K, CS_ADM_sped_cat2_K, CS_ADM_sped_cat3_K, CS_ADM_sped_cat4_K, CS_ADM_sped_cat5_K, CS_ADM_sped_cat6_K, CS_ADM_other_K, CS_ADM_total_K,
             CS_ADM_sped_cat1_1to12, CS_ADM_sped_cat2_1to12, CS_ADM_sped_cat3_1to12, CS_ADM_sped_cat4_1to12, CS_ADM_sped_cat5_1to12, CS_ADM_sped_cat6_1to12, CS_ADM_other_1to12, CS_ADM_total_1to12,
             CS_sped_wtd_funds, CS_formula_amt,
             CS_TOTAL_DEDUCT, CS_JVS_FTE, CS_CTA_cat1_FTE, CS_CTA_cat2_FTE, CS_CTA_total_funds, CS_parity_aid,
                 CS_LEP_FTE, CS_INT_1, CS_INT_2, CS_INT_3, CS_LEP_AID, CS_PBA_PD_AID, 
                  CS_PBA_allday_K, CS_PBA_PD_AID, CS_PBA_CSR, CS_PBA_CO, CS_PBA_GUAR
                 ]

    df2.loc[len(df2)] = list_i
    #list_list= list_list.append(list_i)

df2.to_csv("Community_" + str(YEAR) + "_2.csv")
# Out:
# /var/folders/09/l3m63nj90fg1l2jshjp_hd5w0000gn/T/ipykernel_44998/2915335476.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")
# 48207 0
# 43612 1
# 47167 2
# 46516 3
# 69682 4
# 49122 5
# **** no data ****
# 46037 6
# 46797 7
# **** no data ****
# 47191 8
# 48553 9
# **** no data ****
# 48959 10
# **** no data ****
# 48967 11
# **** no data ****
# 48728 12
# 46268 13
# 44586 14
# 49817 15
# **** no data ****
# 48587 16
# **** no data ****
# 47969 17
# **** no data ****
# 45674 18

# %%
df2
# Out:
#       IRN  year county_code CS_ADM_sped_cat1_K CS_ADM_sped_cat2_K
# 0   48207  2007     fill in               0.00               0.00  \
# 1   43612  2007     fill in               0.00               0.00
# 2   47167  2007     fill in               0.00               0.00
# 3   46516  2007     fill in               0.00               0.00
# 4   69682  2007     fill in               0.00               0.00
# 5   49122  2007     fill in                N/A                N/A
# 6   46037  2007     fill in               0.00               0.00
# 7   46797  2007     fill in                N/A                N/A
# 8   47191  2007     fill in               0.00               0.00
# 9   48553  2007     fill in                N/A                N/A
# 10  48959  2007     fill in                N/A                N/A
# 11  48967  2007     fill in                N/A                N/A
# 12  48728  2007     fill in               0.00               0.00
# ...
