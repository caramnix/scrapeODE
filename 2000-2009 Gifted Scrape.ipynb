# %%
#written 4/27/23 by @caramnix

#code which just scrapes the number of gifted units each school district received per year

# %%
import time 
import pandas as pd 
from selenium import webdriver 
from selenium.webdriver import Chrome 
from selenium.webdriver.chrome.service import Service 
from selenium.webdriver.common.by import By 
from webdriver_manager.chrome import ChromeDriverManager

# %%
#2000 school names 

i=1 
print(list_school_names[i] + " " + str(i))
time.sleep(1)
url = "https://reports.education.ohio.gov/finance/legacy-report" 
driver.get(url)
driver.implicitly_wait(10)
time.sleep(3)

#change this manually -- 
## scrape 2000
YEAR = "2000"
FINAL = "Final #2"
#first step, fill in info, press go 

# fill in LEA type 
text_box_path = '/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input'
text_box = driver.find_element(By.XPATH, text_box_path)
text_box.send_keys("Traditional School District")

text_box_selection_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div"
time.sleep(.25)
drop_box_1 = driver.find_element(By.XPATH, text_box_selection_path)
time.sleep(.25)
drop_box_1.click()

#fill in year 

year_text_box_path ="/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[2]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
year_text_box = driver.find_element(By.XPATH, year_text_box_path)
year_text_box.send_keys(YEAR)

year_drop_select ="/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[2]/ul/li[2]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"
time.sleep(.25)
drop_box_2 = driver.find_element(By.XPATH, year_drop_select)
time.sleep(.25)
drop_box_2.click()

time.sleep(.25)
go_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[3]/button"
time.sleep(.25)
go_button = driver.find_element(By.XPATH, go_path)
time.sleep(.25)

go_button_bool = None
while not go_button_bool:
    try:
        go_button.click()
        go_button_bool=1
    except ElementClickInterceptedException:
        time.sleep(2)


time.sleep(.25)
#next step 

payment_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[3]/div/ul/li/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
payment_path_box = driver.find_element(By.XPATH, payment_path)
time.sleep(.25)

payment_path_box.send_keys(FINAL)
payment_path_selection_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[3]/div/ul/li/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"

time.sleep(.25)
drop_box_3 = driver.find_element(By.XPATH, payment_path_selection_path)
drop_box_3.click()

#next step is to find all LEA values 

lea_box_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
lea_arrow_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div"

#click on arrow to show options 
driver.find_element(By.XPATH, lea_arrow_path).click()

time.sleep(.25)
drop_down_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div"
drop_down= driver.find_element(By.XPATH, drop_down_path)

ddt= drop_down.text
list_school_names_i = ddt.splitlines()
# Out:
# Adams County Ohio Valley Local (Adams) - 061903 1

# %%
list_school_names_i[313]
# Out:
# 'Mansfield City (Richland) - 044297'

# %%
print(list_school_names_i)
# Out:
# ['State Totals (All Counties) - 999999', 'Ada Exempted Village (Hardin) - 045187', 'Adams County Ohio Valley Local (Adams) - 061903', 'Adena Local (Ross) - 049494', 'Akron City (Summit) - 043489', 'Alexander Local (Athens) - 045906', 'Allen East Local (Allen) - 045757', 'Alliance City (Stark) - 043497', 'Amanda-Clearcreek Local (Fairfield) - 046847', 'Amherst Exempted Village (Lorain) - 045195', 'Anna Local (Shelby) - 049759', 'Ansonia Local (Darke) - 046623', 'Anthony Wayne Local (Lucas) - 048207', 'Antwerp Local (Paulding) - 048991', 'Arcadia Local (Hancock) - 047415', 'Arcanum-Butler Local (Darke) - 046631', 'Archbold-Area Local (Fulton) - 047043', 'Arlington Local (Hancock) - 047423', 'Ashland City (Ashland) - 043505', 'Ashtabula Area City (Ashtabula) - 043513', 'Athens City (Athens) - 043521', 'Aurora City (Portage) - 049171', 'Austintown Local Schools (Mahoning) - 048298', 'Avon Lake City (Lorain) - 048124', 'Avon Local (Lorain) - 048116', 'Ayersville Local (Defiance) - 046706', 'Barberton City (Summit) - 043539', 'Barnesville Exempted Village (Belmont) - 045203', 'Batavia Local (Clermont) - 046300', 'Bath Local (Allen) - 045765', 'Bay Village City (Cuyahoga) - 043547', 'Beachwood City (Cuyahoga) - 043554', 'Beaver Local (Columbiana) - 046425', 'Beavercreek City (Greene) - 047241', 'Bedford City (Cuyahoga) - 043562', 'Bellaire Local (Belmont) - 043570', 'Bellbrook-Sugarcreek Local (Greene) - 047274', 'Bellefontaine City (Logan) - 043588', 'Bellevue City (Huron) - 043596', 'Belpre City (Washington) - 043604', 'Benjamin Logan Local (Logan) - 048074', 'Benton Carroll Salem Local (Ottawa) - 048926', 'Berea City (Cuyahoga) - 043612', 'Berkshire Local (Geauga) - 047167', 'Berne Union Local (Fairfield) - 046854', 'Bethel Local (Miami) - 048611', 'Bethel-Tate Local (Clermont) - 046318', 'Bettsville Local (Seneca) - 049692', 'Bexley City (Franklin) - 043620', 'Big Walnut Local (Delaware) - 046748', 'Black River Local (Medina) - 048462', 'Blanchester Local (Clinton) - 046383', 'Bloom-Carroll Local (Fairfield) - 046862', 'Bloom-Vernon Local (Scioto) - 049593', 'Bloomfield-Mespo Local (Trumbull) - 050096', 'Bluffton Exempted Village (Allen) - 045211', 'Boardman Local (Mahoning) - 048306', 'Botkins Local (Shelby) - 049767', 'Bowling Green City School District (Wood) - 043638', 'Bradford Exempted Village (Miami) - 045229', 'Brecksville-Broadview Heights City (Cuyahoga) - 043646', 'Bridgeport Exempted Village (Belmont) - 045237', 'Bright Local (Highland) - 047613', 'Bristol Local (Trumbull) - 050112', 'Brookfield Local (Trumbull) - 050120', 'Brooklyn City (Cuyahoga) - 043653', 'Brookville Local (Montgomery) - 048678', 'Brown Local (Carroll) - 046177', 'Brunswick City (Medina) - 043661', 'Bryan City (Williams) - 043679', 'Buckeye Central Local (Crawford) - 046508', 'Buckeye Local (Jefferson) - 047787', 'Buckeye Local (Medina) - 048470', 'Buckeye Local (Ashtabula) - 045856', 'Buckeye Valley Local (Delaware) - 046755', 'Bucyrus City (Crawford) - 043687', 'Caldwell Exempted Village (Noble) - 045252', 'Cambridge City (Guernsey) - 043695', 'Campbell City (Mahoning) - 043703', 'Canal Winchester Local (Franklin) - 046946', 'Canfield Local (Mahoning) - 048314', 'Canton City (Stark) - 043711', 'Canton Local (Stark) - 049833', 'Cardinal Local (Geauga) - 047175', 'Cardington-Lincoln Local (Morrow) - 048793', 'Carey Exempted Village Schools (Wyandot) - 045260', 'Carlisle Local (Warren) - 050419', 'Carrollton Exempted Village (Carroll) - 045278', 'Cedar Cliff Local (Greene) - 047258', 'Celina City (Mercer) - 043729', 'Centerburg Local (Knox) - 047829', 'Centerville City (Montgomery) - 043737', 'Central Local (Defiance) - 046714', 'Chagrin Falls Exempted Village (Cuyahoga) - 045286', 'Champion Local (Trumbull) - 050138', 'Chardon Local (Geauga) - 047183', 'Chesapeake Union Exempted Village (Lawrence) - 045294', 'Chillicothe City (Ross) - 043745', 'Chippewa Local (Wayne) - 050534', 'Cincinnati Public Schools (Hamilton) - 043752', 'Circleville City (Pi ...

# %%
#ddt= drop_down.text
#list_school_names = ddt.splitlines()

# %%
from selenium import webdriver
#set chromodriver.exe path
driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")
driver.implicitly_wait(0.5)

# %%
colnames= ["IRN", "year", "county_code", "GT_units"] 
#df = pd.DataFrame(columns = colnames)

# %%
from selenium.common.exceptions import ElementClickInterceptedException, NoSuchElementException

# %%
#list_list= [] 
for i in range(1, len(list_school_names)): 
    print(list_school_names[i] + " " + str(i))
    time.sleep(1)
    url = "https://reports.education.ohio.gov/finance/legacy-report" 
    driver.get(url)
    driver.implicitly_wait(10)
    time.sleep(3)
    
    ## scrape 2000
    YEAR = "2000"
    FINAL = "Final #2"
    #first step, fill in info, press go 

    # fill in LEA type 
    text_box_path = '/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input'
    text_box = driver.find_element(By.XPATH, text_box_path)
    text_box.send_keys("Traditional School District")

    text_box_selection_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div"
    time.sleep(.25)
    drop_box_1 = driver.find_element(By.XPATH, text_box_selection_path)
    time.sleep(.25)
    drop_box_1.click()

    #fill in year 

    year_text_box_path ="/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[2]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    year_text_box = driver.find_element(By.XPATH, year_text_box_path)
    year_text_box.send_keys(YEAR)
    
    year_drop_select ="/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[2]/ul/li[2]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"
    time.sleep(.25)
    drop_box_2 = driver.find_element(By.XPATH, year_drop_select)
    time.sleep(.25)
    drop_box_2.click()
    
    time.sleep(.25)
    go_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div/div/div/div[2]/ul/li[3]/button"
    time.sleep(.25)
    go_button = driver.find_element(By.XPATH, go_path)
    time.sleep(.25)
    
    go_button_bool = None
    while not go_button_bool:
        try:
            go_button.click()
            go_button_bool=1
        except ElementClickInterceptedException:
            time.sleep(2)
    

    time.sleep(.25)
    #next step 

    payment_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[3]/div/ul/li/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    payment_path_box = driver.find_element(By.XPATH, payment_path)
    time.sleep(.25)

    payment_path_box.send_keys(FINAL)
    payment_path_selection_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[1]/div/div/div[3]/div/ul/li/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"
    
    time.sleep(.25)
    drop_box_3 = driver.find_element(By.XPATH, payment_path_selection_path)
    drop_box_3.click()

    #next step is to find all LEA values 

    lea_box_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    lea_arrow_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div"

    #click on arrow to show options 
    driver.find_element(By.XPATH, lea_arrow_path).click()

    time.sleep(.25)
    drop_down_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div"
    drop_down= driver.find_element(By.XPATH, drop_down_path)
    
    drop_down_school_district_path= "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    drop_down_school_district= driver.find_element(By.XPATH, drop_down_school_district_path)
    just_name =list_school_names[i].split("(")[0].strip()
    #try doing by key. 
    IRA_i = list_school_names[i].split()[-1]
    drop_down_school_district.send_keys(IRA_i) #list_school_names[i])

    school_district_select_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"
     
    drop_box_4 = driver.find_element(By.XPATH, school_district_select_path)
        
    drop_button_bool = None
    while not drop_button_bool:
        try:
            drop_box_4 = driver.find_element(By.XPATH, school_district_select_path)
            drop_button_bool=1
        except NoSuchElementException:
            time.sleep(2)
            
            
    #except NoSuchElementException: 
    #    drop_down_school_district_path= "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/div/div/div[3]/input"
    #    drop_down_school_district= driver.find_element(By.XPATH, drop_down_school_district_path)
    #    just_name =list_school_names[i].split("(")[0].strip()
    #    drop_down_school_district.send_keys(just_name)
    #    drop_box_4 = driver.find_element(By.XPATH, school_district_select_path)
        
    drop_box_4.click()

    time.sleep(.25)
    #click process button! 
    process_button_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[3]/ul/li[2]/button"
    driver.find_element(By.XPATH, process_button_path).click()
    time.sleep(4)
    
    ## new code here     
    
    testing_web_text= driver.page_source
    GT_units= testing_web_text.split("Gifted Aid")[1].split("\n")[0].split()[1]

    IRA_i = list_school_names[i].split()[-1]
    county_i= list_school_names[i].split("(")[1].split()[0].split(")")[0]
    
    list_i = [IRA_i, YEAR, county_i, GT_units]
    
    #print(list_i)

    df.loc[len(df)] = list_i
    #list_list= list_list.append(list_i)
# Out:
# Mansfield City (Richland) - 044297 313
# Maple Heights City (Cuyahoga) - 044305 314
# Mapleton Local (Ashland) - 045831 315
# Maplewood Local (Trumbull) - 050211 316
# Margaretta Local (Erie) - 046805 317
# Mariemont City (Hamilton) - 044313 318
# Marietta City (Washington) - 044321 319
# Marion City (Marion) - 044339 320
# Marion Local (Mercer) - 048553 321
# Marlington Local (Stark) - 049882 322
# Martins Ferry City (Belmont) - 044347 323
# Marysville Exempted Village (Union) - 045476 324
# Mason City (Warren) - 050450 325
# Massillon City (Stark) - 044354 326
# Mathews Local (Trumbull) - 050153 327
# Maumee City (Lucas) - 044362 328
# Mayfield City (Cuyahoga) - 044370 329
# Maysville Local (Muskingum) - 048850 330
# McComb Local (Hancock) - 047456 331
# McDonald Local (Trumbull) - 050229 332
# Mechanicsburg Exempted Village (Champaign) - 045484 333
# Medina City SD (Medina) - 044388 334
# Meigs Local (Meigs) - 048520 335
# Mentor Exempted Village (Lake) - 045492 336
# Miami East Local (Miami) - 048629 337
# Miami Trace Local (Fayette) - 046920 338
# Miamisburg City (Montgomery) - 044396 339
# Middle Bass Local (Ottawa) - 048959 340
# Middletown City (Butler) - 044404 341
# Midview Local (Lorain) - 048173 342
# Milford Exempted Village (Clermont) - 045500 343
# Millcreek-West Unity Local (Williams) - 050633 344
# Miller City-New Cleveland Local (Putnam) - 049361 345
# Milton-Union Exempted Village (Miami) - 045518 346
# Minerva Local (Stark) - 049890 347
# Minford Local (Scioto) - 049627 348
# Minster Local (Auglaize) - 045948 349
# Mississinawa Valley Local (Darke) - 046672 350
# Mogadore Local (Summit) - 050039 351
# Mohawk Local (Wyandot) - 050740 352
# Monroe Local (Butler) - 139303 353
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[92], line 88
#      84 drop_down_school_district.send_keys(IRA_i) #list_school_names[i])
#      86 school_district_select_path = "/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"
# ---> 88 drop_box_4 = driver.find_element(By.XPATH, school_district_select_path)
#      90 drop_button_bool = None
#      91 while not drop_button_bool:
#
# File ~/anaconda3/envs/sarascrape/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:831, in WebDriver.find_element(self, by, value)
#     828     by = By.CSS_SELECTOR
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/anaconda3/envs/sarascrape/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~/anaconda3/envs/sarascrape/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/app-root/eas-ui-lib-spinner/div/eas-core-application-container/div/div[2]/as-split/as-split-area[2]/div/div/app-legacy-reports/lib-legacy-report/div[2]/div/div/div/div/div[1]/eas-ui-lib-form-group/label/ng-select/ng-dropdown-panel/div/div[2]/div/span"}
#   (Session info: chrome=112.0.5615.137)
# Stacktrace:
# 0   chromedriver                        0x0000000102db9670 chromedriver + 4298352
# 1   chromedriver                        0x0000000102db1bbc chromedriver + 4266940
# 2   chromedriver                        0x00000001029e4758 chromedriver + 280408
# 3   chromedriver                        0x0000000102a1fb38 chromedriver + 523064
# 4   chromedriver                        0x0000000102a58080 chromedriver + 753792
# 5   chromedriver                        0x0000000102a122d0 chromedriver + 467664
# 6   chromedriver                        0x0000000102a13354 chromedriver + 471892
# 7   chromedriver                        0x0000000102d796c4 chromedriver + 4036292
# 8   chromedriver                        0x0000000102d7dc64 chromedriver + 4054116
# 9   chromedriver                        0x0000000102d842d8 chromedriver + 4080344
# 10  chromedriver                        0x0000000102d7e970 chromedriver + 4057456
# 11  chromedriver                        0x0000000102d558dc chromedriver + 3889372
# 12  chromedriver                        0x0000000102d9d25c chromedriver + 4182620
# 13  chromedriver                        0x0000000102d9d3b4 chromedriver + 4182964
# 14  chromedriver                        0x0000000102dac0f4 chromedriver + 4243700
# 15  libsystem_pthread.dylib             0x00000001972e3fa8 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001972deda0 thread_start + 8

# %%
df.to_csv("/Gifted_2000_partial.csv")

# columns: IRN    year   county_code   GT_units
# row 1  : 5187   2000     Hardin        0.5
